# %%
#Yields lists of words representing 1 line each
def file_to_words(filename):
    #Only alphabets and lowercase
    def clean_word(word):
        return "".join([c if (c.isalpha() or c == "'") else '' for c in word]).lower()
        
    #open file
    with open(filename) as infile:
        #Go through lines
        for line in infile:
            #Trim and split
            words = line.strip().split()
            #No [Singer] tags
            no_bracket_words = [word for word in words if word[0] != '[']
            
            #check if empty
            if not no_bracket_words:
                continue
            #Clean words
            cleaned_words = [clean_word(word) for word in no_bracket_words]
            #yield cleaned words
            for word in cleaned_words:
                yield word
            #yield newline
            yield '\n'

# %%
list(file_to_words('lyrics/Imagine-dragons-on-top-of-the-world-lyrics.txt'))[:10]
# Out:
# ['', '\n', 'if', 'you', 'love', 'somebody', '\n', 'better', 'tell', 'them']

# %%
import os
def get_all_filenames(directory):
    #https://stackoverflow.com/questions/120656/directory-listing-in-python
    return os.listdir(directory)

# %%
get_all_filenames('lyrics')[:10]
# Out:
# ['Imagine-dragons-leave-me-lyrics.txt',
#  'Imagine-dragons-uptight-lyrics.txt',
#  'Imagine-dragons-on-top-of-the-world-lyrics.txt',
#  'Imagine-dragons-volume-drops-lyrics.txt',
#  'Imagine-dragons-gold-lyrics.txt',
#  'Imagine-dragons-amsterdam-lyrics.txt',
#  'Imagine-dragons-february-lyrics.txt',
#  'Imagine-dragons-battle-cry-lyrics.txt',
#  'Imagine-dragons-pistol-whip-lyrics.txt',
#  'Imagine-dragons-thief-lyrics.txt']

# %%
def words_to_bigrams(words):
    #Use zip to combine, shifted left, shifted right
    return zip(words[:-1], words[1:])

# %%
list(words_to_bigrams(['if', 'you', 'love', 'somebody', '\n', 'better', 'tell', 'them']))
# Out:
# [('if', 'you'),
#  ('you', 'love'),
#  ('love', 'somebody'),
#  ('somebody', '\n'),
#  ('\n', 'better'),
#  ('better', 'tell'),
#  ('tell', 'them')]

# %%
def add_bigrams_to_dict(d, bigrams):
    #go through bigrams
    for bigram in bigrams:
        #Extract words
        first, second = bigram
        #If first isnt there
        if first not in d:
            d[first] = {}
        #If second isnt there
        if second not in d[first]:
            d[first][second] = 0
        #Increment
        d[first][second] += 1

# %%
from random import randint
def random_weighted_key(d):
    #calculate total sum
    total_value = sum(d.values())
    rand_value = randint(0, total_value)
    #iterate through keys and values
    for k, v in d.items():
        #Update rand value
        rand_value -= v
        #See if we've reached the right number
        if rand_value <= 0:
            return k

# %%
def build_count_dict(directory):
    count_dict = {}
    for filename in get_all_filenames(directory):
        full_filename = directory + '/' + filename
        bigrams = words_to_bigrams(list(file_to_words(full_filename)))
        add_bigrams_to_dict(count_dict, bigrams)
    return count_dict

# %%
build_count_dict('lyrics')
# Out:
# {'': {'': 21,
#   '\n': 208,
#   'am': 9,
#   'boys': 3,
#   'chorus': 1,
#   "i'm": 6,
#   "it's": 1,
#   'mirrors': 1,
#   'nothing': 1,
#   'rocks': 1,
#   'take': 1,
#   'they': 3,
#   'whoa': 2},
#  'halls': {'\n': 1},
#  'under': {'\n': 5},
#  'look': {'\n': 2,
#   'and': 1,
#   'at': 4,
#   'back': 2,
#   'clear': 5,
#   'down': 8,
#   'for': 1,
#   'how': 9,
#   'in': 5,
#   'inside': 1,
#   'into': 3,
#   'look': 4,
#   'on': 3,
#   'out': 8,
#   'so': 1,
#   'that': 4,
#   'the': 2,
#   'through': 2,
#   'tired': 1,
#   'to': 2,
#   'you': 3},
#  'limited': {'\n': 2},
#  'place': {'\n': 3, 'so': 3, 'that': 4, 'to': 1},
#  'thunder': {'\n': 24, 'feel': 9, 'lost': 1, 'roars': 1, 'thunder': 6},
#  'dug': {'your': 1},
#  'night': {'\n': 31,
#   'and': 1,
#   'every': 33,
#   'go': 2,
#   "i'll": 9,
#   'light': 1,
#   'stands': 1,
#   'too': 1,
#   'with': 1},
#  'mumble': {'\n': 1},
#  'growing': {'old': 1, 'older': 1},
#  'crystallized': {'\n': 1},
#  'searching': {'\n': 1, 'to': 1},
#  'led': {'me': 6},
#  'lying': {'in': 1},
#  'pane': {'\n': 2},
#  'cries': {'from': 1},
#  "king's": {'lair': 1},
#  'send': {'a': 1},
#  'beauty': {'through': 1},
#  'team': {'\n': 1},
#  'deeds': {'\n': 1},
#  'rings': {'\n': 2},
#  'baggage': {'\n': 2},
#  'curtains': {'drawn': 1},
#  'same': {'\n': 3,
#   'as': 5,
#   'ohoh': 1,
#   'old': 9,
#   'play': 2,
#   'through': 1,
#   'way': 4,
#   'when': 1},
#  'cold': {'\n': 1,
#   'and': 1,
#   'at': 1,
#   "night's": 1,
#   'nights': 1,
#   'out': 1,
#   'pit': 1,
#   'sheets': 1,
#   'to': 1},
#  'closed': {'\n': 1},
#  'stay': {'\n': 5,
#   'forever': 3,
#   'here': 5,
#   'i': 2,
#   'the': 1,
#   'up': 6,
#   'with': 20},
#  'spinning': {'\n': 1},
#  'much': {'\n': 2,
#   'longer': 2,
#   'more': 1,
#   'on': 1,
#   'so': 1,
#   'there': 1,
#   'too': 1},
#  'cigarettes': {'politics': 1},
#  'wall': {'\n': 3, 'dont': 1, 'the': 1},
#  'because': {'\n': 3,
#   'i': 5,
#   "i'm": 4,
#   'im': 4,
#   'thirty': 1,
#   'you': 1,
#   'your': 1},
#  'smiled': {'and': 1},
#  'passed': {'more': 1},
#  'possible': {'that': 1},
#  "discernin'": {'it': 1},
#  'runs': {'out': 1, 'through': 2},
#  'lip': {'\n': 2, 'lip': 2},
#  'closing': {'my': 1},
#  'apostrophe': {'\n': 1},
#  "heater's": {'gone': 1},
#  'fast': {'lane': 4, 'to': 4},
#  'polaroid': {'\n': 2, 'oh': 3, 'ohaoh': 2},
#  'casing': {'shaking': 1},
#  "throwin'": {'me': 1},
#  'sinking': {'in': 1, 'to': 4},
#  'hands': {'\n': 8, 'are': 1, 'been': 1, 'of': 8, 'run': 1},
#  'roams': {'around': 4},
#  'beckon': {'us': 1},
#  'think': {'\n': 3,
#   'a': 2,
#   'all': 3,
#   'he': 1,
#   'i': 4,
#   "i'm": 1,
#   'im': 4,
#   "it's": 1,
#   'itd': 1,
#   'my': 1,
#   'of': 2,
#   'that': 8,
#   "we'd": 2,
#   "we're": 1,
#   'when': 3,
#   'you': 2},
#  'along': {'\n': 1, 'into': 1, 'the': 1, 'to': 1, 'with': 2},
#  'twoface': {'\n': 1},
#  'world': {'\n': 13,
#   'america': 3,
#   'and': 1,
#   'are': 2,
#   'class': 1,
#   'come': 1,
#   'could': 2,
#   'has': 1,
#   'hey': 10,
#   'is': 2,
#   'lie': 1,
#   'say': 1,
#   'turns': 1,
#   "wasn't": 1},
#  'crow': {'\n': 1},
#  'quite': {'the': 1, 'thought': 1, 'when': 1},
#  'bad': {'as': 4},
#  'played': {'\n': 1, 'sacrificed': 1},
#  'gave': {'her': 1, 'it': 6, 'until': 1, 'up': 1, 'you': 2},
#  'carrying': {'pictures': 1},
#  'fault': {'\n': 8, 'is': 8},
#  'interest': {'\n': 1},
#  'stopped': {'in': 1},
#  'broken': {'but': 4,
#   'from': 1,
#   'head': 1,
#   'hearts': 1,
#   'home': 1,
#   'homes': 1,
#   'in': 1,
#   'maybe': 1,
#   'town': 2},
#  'paying': {'my': 5},
#  'clear': {'\n': 7, 'my': 1, 'of': 1},
#  'saint': {"i've": 1},
#  'purple': {'\n': 1},
#  'eye': {'\n': 7, 'filling': 1},
#  "screamin'": {'and': 1},
#  'entertain': {'\n': 1},
#  'walls': {"they're": 2},
#  'ride': {'\n': 1, 'it': 2},
#  'guitar': {'solo': 1},
#  'doors': {"won't": 2},
#  'stars': {'\n': 1, 'are': 2, 'look': 5, 'on': 3, 'parade': 1, 'that': 2},
#  'caesar': {'\n': 1},
#  'small': {'seed': 1},
#  'faith': {'\n': 1, "ain't": 1, 'and': 3},
#  'ripcord': {'\n': 2},
#  'competent': {'fool': 1},
#  'simple': {'situation': 6},
#  'kites': {'\n': 1},
#  'shallow': {'grave': 4},
#  'appear': {'but': 1},
#  'bleeds': {'\n': 1},
#  'victim': {'\n': 1},
#  'kind': {'\n': 3, 'of': 4},
#  'countless': {'times': 4},
#  'would': {'always': 4,
#   'beg': 2,
#   'change': 1,
#   'drown': 1,
#   'i': 3,
#   'make': 2,
#   'never': 4,
#   'rather': 5,
#   'wait': 1,
#   'walk': 8,
#   'you': 4},
#  'change': {'\n': 5,
#   'a': 1,
#   'and': 1,
#   'my': 3,
#   'that': 4,
#   'the': 3,
#   'with': 1,
#   'your': 5},
#  'latest': {'midnight': 1},
#  'egotistical': {'\n': 1},
#  'had': {'\n': 1,
#   'a': 8,
#   'all': 1,
#   'enough': 1,
#   'in': 2,
#   'one': 2,
#   'the': 3,
#   'to': 3,
#   'what': 1},
#  'metaphoric': {'fall': 1},
#  'beneath': {'the': 1},
#  'ghost': {'\n': 1},
#  'make': {'a': 10,
#   'believe': 2,
#   'broke': 1,
#   'i': 1,
#   'it': 20,
#   'me': 8,
#   'my': 5,
#   'no': 2,
#   'some': 1,
#   'this': 1,
#   'you': 5},
#  'thee': {'\n': 1},
#  'trust': {'\n': 7, 'me': 1},
#  'coming': {'\n': 6, 'back': 1, 'for': 8, 'home': 15, 'in': 4, 'up': 3},
#  'rush': {'way': 2},
#  'classes': {'\n': 1},
#  'checking': {'out': 2},
#  'move': {'\n': 2, "'til": 1, 'passed': 1},
#  'taking': {'a': 5, 'down': 1, 'first': 1, 'its': 1, 'my': 3, 'over': 1},
#  'mr': {'cage': 2, 'fate': 1, 'motion': 1, 'post': 1, 'safe': 1},
#  'hope': {'\n': 4, "it's": 1, 'to': 3, 'you': 2},
#  'that': {'\n': 23,
#   'all': 2,
#   'beatup': 1,
#   'beckon': 1,
#   'blindfold': 1,
#   'built': 6,
#   'burn': 1,
#   'comes': 3,
#   'dark': 1,
#   'diamond': 1,
#   'distracts': 1,
#   'divides': 1,
#   'dynamite': 3,
#   'everyone': 1,
#   'everythings': 3,
#   'fall': 1,
#   'fly': 1,
#   'follow': 1,
#   'gathers': 1,
#   'gave': 1,
#   'goes': 1,
#   'golden': 1,
#   'grows': 1,
#   'hang': 1,
#   'have': 4,
#   'how': 1,
#   'i': 40,
#   "i'd": 2,
#   "i'll": 1,
#   "i'm": 11,
#   "i've": 4,
#   'im': 1,
#   "isn't": 2,
#   'it': 1,
#   "it's": 2,
#   'ive': 1,
#   'light': 1,
#   'line': 1,
#   'london': 1,
#   'look': 5,
#   'made': 1,
#   'matter': 2,
#   'never': 1,
#   'nothing': 1,
#   'only': 1,
#   'pit': 4,
#   'provides': 1,
#   'rides': 1,
#   'road': 1,
#   'roams': 4,
#   'ruffles': 1,
#   'runs': 1,
#   'sounds': 6,
#   'speak': 3,
#   'symbolize': 1,
#   'the': 1,
#   "there's": 1,
#   'things': 2,
#   'this': 6,
#   'time': 1,
#   'walks': 1,
#   'was': 1,
#   'way': 4,
#   'we': 10,
#   "we'd": 2,
#   "we'll": 1,
#   "we're": 5,
#   "we've": 5,
#   'what': 1,
#   'worry': 1,
#   'you': 26,
#   "you'd": 2,
#   "you'll": 1,
#   "you've": 3},
#  'shaded': {'tree': 1},
#  'followed': {'this': 1},
#  'needs': {'a': 1, 'to': 1},
#  'brow': {'and': 1},
#  'privilege': {'\n': 1},
#  'selfless': {'man': 1},
#  'lie': {'\n': 5, 'and': 3, 'of': 2, 'oh': 1, 'on': 1},
#  'volume': {'drops': 3},
#  'apart': {'\n': 9},
#  'réponds': {'pas': 1},
#  'scheming': {'for': 1},
#  'city': {'beat': 1, 'never': 2, 'of': 10, "she's": 1, 'where': 2},
#  'mine': {'\n': 4, 'and': 2, 'you': 3},
#  'preacher': {'i': 1},
#  'sheets': {'\n': 1},
#  'till': {'it': 2, 'we': 2, "we're": 1, 'you': 9, 'youve': 3},
#  'brave': {'\n': 3},
#  'worst': {'of': 3},
#  'giver': {'\n': 6},
#  'swing': {'low': 1},
#  'pawn': {'in': 1, 'within': 2},
#  'poisoned': {'inside': 1},
#  'staining': {'everything': 1},
#  'part': {'': 2, 'of': 3, 'time': 1},
#  'cockatoos': {'\n': 1},
#  'enemies': {'\n': 1, 'are': 1},
#  'mama': {'blessed': 1},
#  'twostep': {'off': 3},
#  'hurry': {'\n': 1},
#  'vacant': {'alibi': 1},
#  'throne': {'above': 1},
#  'luck': {'\n': 8, 'am': 1},
#  'sister': {'\n': 3, 'give': 3},
#  'work': {'a': 1, 'i': 1, 'while': 1},
#  'if': {'all': 2,
#   "he's": 2,
#   'i': 36,
#   "i'm": 1,
#   "it's": 1,
#   'its': 12,
#   'my': 1,
#   'one': 1,
#   'only': 5,
#   'the': 4,
#   'we': 3,
#   'weve': 5,
#   'you': 23,
#   "you're": 1,
#   "you've": 4},
#  'breaking': {'\n': 1, 'hiding': 1, 'in': 2, 'me': 1, 'up': 2},
#  'yellow': {'raft': 2},
#  'proud': {'of': 1},
#  'disappear': {'dream': 1},
#  'ticket': {'for': 1},
#  'open': {'\n': 2, 'and': 2, 'places': 2, 'up': 28},
#  'got': {'\n': 10,
#   'a': 20,
#   'all': 3,
#   'me': 5,
#   'my': 18,
#   'no': 4,
#   'nothing': 2,
#   'one': 2,
#   'religious': 1,
#   'something': 10,
#   'the': 2,
#   'this': 3,
#   'to': 22,
#   'when': 1},
#  'aint': {'what': 3},
#  'dry': {'\n': 1},
#  'grabbed': {'the': 2},
#  'bubbling': {'up': 1},
#  'longer': {'cause': 2, 'feel': 1},
#  'astrology': {'or': 1},
#  'hard': {'and': 1,
#   'believe': 4,
#   'enough': 1,
#   'for': 1,
#   'on': 1,
#   'to': 7,
#   'when': 2,
#   'year': 2},
#  'crumble': {'away': 3},
#  'stuck': {'in': 3},
#  'tier': {'of': 1},
#  'great': {'big': 1},
#  'such': {'a': 2},
#  'afraid': {'\n': 2, 'just': 3, 'of': 1},
#  'mass': {'\n': 1},
#  'grown': {'\n': 1},
#  'trends': {'\n': 1},
#  'to': {'\n': 10,
#   "'": 1,
#   'a': 1,
#   'age': 3,
#   'all': 2,
#   'ash': 1,
#   'ashes': 2,
#   'be': 71,
#   'beat': 3,
#   'begin': 5,
#   'believe': 11,
#   'bend': 1,
#   'blame': 1,
#   'break': 1,
#   'bring': 5,
#   'build': 2,
#   'burn': 3,
#   'bury': 1,
#   'capture': 4,
#   'carfilled': 1,
#   'catch': 1,
#   'cave': 1,
#   'change': 11,
#   'chase': 2,
#   'come': 9,
#   'conceive': 1,
#   'cry': 1,
#   'cut': 1,
#   'dance': 1,
#   'death': 2,
#   'determine': 1,
#   'die': 5,
#   'disappear': 1,
#   'do': 29,
#   'dream': 4,
#   'drift': 2,
#   'eat': 2,
#   'entice': 1,
#   'escape': 4,
#   'every': 3,
#   'everyone': 1,
#   'face': 4,
#   'fail': 1,
#   'fall': 4,
#   'fate': 1,
#   'feel': 4,
#   'fight': 1,
#   'fill': 2,
#   'find': 10,
#   'fit': 5,
#   'follow': 1,
#   'forget': 1,
#   'get': 14,
#   'give': 1,
#   'go': 16,
#   'gold': 12,
#   'guide': 3,
#   'have': 2,
#   'hear': 3,
#   'heaven': 1,
#   'hell': 1,
#   'hide': 3,
#   'hit': 5,
#   'hold': 8,
#   'hurry': 1,
#   'just': 1,
#   'keep': 1,
#   'know': 3,
#   'last': 1,
#   'learn': 4,
#   'leave': 16,
#   'let': 2,
#   'lie': 4,
#   'life': 2,
#   'live': 4,
#   'look': 1,
#   'lose': 1,
#   'love': 4,
#   'make': 14,
#   'matter': 2,
#   'me': 53,
#   'meet': 5,
#   'mine': 3,
#   'move': 2,
#   'my': 31,
#   'myself': 2,
#   'nothing': 2,
#   'pay': 8,
#   'place': 3,
#   'please': 1,
#   'pour': 1,
#   'prepare': 1,
#   'press': 6,
#   'read': 1,
#   'remind': 1,
#   'ride': 2,
#   'rise': 2,
#   'run': 5,
#   'sail': 1,
#   'save': 1,
#   'say': 20,
#   'search': 1,
#   'see': 11,
#   'shelter': 1,
#   'shore': 2,
#   'shout': 1,
#   'show': 1,
#   'simmer': 4,
#   'sleep': 1,
#   'smile': 5,
#   'smoke': 1,
#   'spend': 8,
#   'stand': 1,
#   'stare': 1,
#   'start': 2,
#   'stay': 3,
#   'stray': 1,
#   'take': 14,
#   'talk': 1,
#   'tears': 2,
#   'ten': 1,
#   'the': 92,
#   'them': 3,
#   'this': 3,
#   'turn': 3,
#   'wait': 1,
#   'walk': 1,
#   'war': 3,
#   'where': 4,
#   'win': 1,
#   'wine': 1,
#   'work': 1,
#   'yell': 1,
#   'yesterday': 5,
#   'you': 60,
#   'your': 3,
#   'yours': 2,
#   'yuendemu': 1},
#  'pace': {'\n': 3, 'pace': 4},
#  'press': {'on': 6},
#  'strapped': {'tight': 6},
#  'voices': {'\n': 10, 'of': 1, 'so': 2},
#  'july': {'\n': 1},
#  'wildest': {'dreams': 1},
#  "'em": {'\n': 1, 'down': 1, 'know': 4, 'over': 4, 'right': 4, 'up': 5},
#  'follow': {'\n': 3, 'a': 1, 'in': 2, 'it': 2, 'my': 3, 'you': 1, 'your': 1},
#  'crazy': {'\n': 10, "i've": 2},
#  'headache': {'and': 1},
#  "night's": {'intake': 1},
#  'melodic': {'melodies': 1},
#  'alley': {'walker': 1},
#  'memory': {'out': 4},
#  'au': {'revoir': 1},
#  'grow': {'\n': 2, 'and': 1, 'old': 1, 'older': 3},
#  'barely': {'knew': 4, 'swim': 1},
#  'le': {'soir': 1},
#  'thought': {'\n': 3, 'i': 3, 'it': 2, 'of': 1, 'we': 1},
#  'drunk': {'next': 1, 'well': 1},
#  'always': {'a': 2,
#   'be': 2,
#   'come': 2,
#   'dangerous': 3,
#   'got': 2,
#   'had': 1,
#   'hanging': 1,
#   'keeping': 1,
#   'knew': 1,
#   'leaving': 1,
#   'let': 4,
#   'living': 1,
#   "lookin'": 1,
#   'looking': 4,
#   'love': 8,
#   'nice': 4,
#   'on': 1,
#   'open': 4,
#   'riding': 1,
#   'see': 1,
#   'time': 2,
#   'up': 4,
#   'what': 1},
#  'clenched': {'teeth': 1},
#  'expectations': {'\n': 3},
#  'toe': {'higher': 1},
#  'begun': {'\n': 1},
#  'fathers': {'\n': 1},
#  'candlelight': {'\n': 1},
#  'rest': {'\n': 1, 'is': 2},
#  'overfed': {'\n': 3},
#  'uptight': {'\n': 4, 'i': 4, 'wanna': 1},
#  'skip': {'the': 3},
#  'fleeting': {'thoughts': 1},
#  'fully': {'clear': 1, 'pleading': 1},
#  'très': {'bien': 1},
#  'emotions': {'flying': 1},
#  'traveled': {'all': 1},
#  'lat': {'da': 24},
#  'caught': {'in': 6, 'up': 2},
#  'sitting': {'here': 1},
#  'fears': {'and': 1, 'where': 1},
#  'evolution': {'\n': 1},
#  'postponed': {'all': 1},
#  'rover': {'\n': 4},
#  'vice': {'or': 1},
#  'flowers': {'bloom': 4},
#  'letdown': {'\n': 1},
#  "greeter's": {'still': 1},
#  'fight': {'\n': 2, 'it': 14, 'the': 6},
#  'symbol': {'to': 1},
#  'pull': {'me': 2},
#  'destined': {'to': 1},
#  'hide': {'\n': 9, 'beneath': 1, "it's": 6, 'oh': 1, 'the': 2},
#  'prisoners': {'wait': 2},
#  'passing': {'in': 2},
#  'remember': {'\n': 1, 'when': 4},
#  "we're": {"'posed": 2,
#   'begging': 1,
#   'caught': 3,
#   'coming': 4,
#   'crazy': 9,
#   'facing': 1,
#   'far': 1,
#   'flying': 1,
#   'going': 2,
#   'gonna': 1,
#   'just': 2,
#   'living': 3,
#   'making': 1,
#   'moving': 16,
#   'not': 2,
#   'older': 1,
#   'painted': 1,
#   'seeing': 4,
#   'setting': 1,
#   'sinking': 4,
#   'the': 2,
#   'walking': 9},
#  'silence': {'emma': 1, 'i': 7, 'screaming': 1, 'screams': 1, 'version': 1},
#  'starry': {'\n': 1, 'nights': 1},
#  'youve': {'made': 7},
#  'washed': {'away': 1},
#  'rain': {'\n': 4,
#   'check': 2,
#   'down': 6,
#   'it': 1,
#   'to': 1,
#   'up': 1,
#   "won't": 1},
#  'street': {'meeting': 4},
#  'ah': {'\n': 4, 'ah': 2, 'dismoi': 2, 'ooo': 2},
#  'dinner': {'bells': 1},
#  'though': {'eyes': 1, 'i': 1, 'our': 1, 'this': 1},
#  'thin': {'\n': 1},
#  'bottle': {'of': 4},
#  'ease': {'it': 11},
#  'turning': {'\n': 6, 'pages': 4, 'stale': 1},
#  'ever': {'changing': 1,
#   'feel': 2,
#   'get': 7,
#   'leave': 1,
#   'lived': 2,
#   'since': 1,
#   'wanna': 10},
#  'guy': {'\n': 4},
#  'thinking': {'i': 2},
#  'listen': {'\n': 1, 'to': 1},
#  'forgive': {'me': 7},
#  'feet': {'\n': 1},
#  "money's": {'high': 2, 'tight': 1},
#  'darkness': {'\n': 8, 'fed': 1, 'right': 2, 'when': 1, 'will': 1},
#  'rides': {'below': 1},
#  'veins': {'\n': 8, 'ohooh': 2},
#  'maker': {'life': 2},
#  'sorry': {'\n': 13,
#   'brother': 1,
#   'for': 4,
#   'i': 3,
#   'lover': 1,
#   'mother': 1,
#   'never': 3},
#  'fighting': {'\n': 1, 'brothers': 1},
#  'searched': {'deep': 1},
#  'hold': {'back': 2, 'hold': 12, 'my': 2, 'on': 15, 'you': 1, 'your': 4},
#  'tale': {'\n': 1},
#  'setting': {'sun': 1, 'up': 1},
#  'grayest': {'drown': 4},
#  'dreams': {'\n': 2, 'all': 1, 'but': 1, 'could': 1, 'of': 1},
#  'field': {'with': 3},
#  'fields': {'\n': 1},
#  'mara': {'i': 1},
#  'rip': {'\n': 2, 'rip': 2},
#  'unknown': {'\n': 1},
#  'playing': {'but': 2, 'from': 1},
#  'afternoon': {'\n': 1, 'oh': 1},
#  'flowing': {'\n': 2},
#  'ocean': {'fall': 1, 'side': 1},
#  'big': {'mass': 1, 'news': 2, 'star': 1},
#  'saw': {'\n': 1, 'was': 1},
#  'loved': {'\n': 7, 'till': 3},
#  'mouth': {'\n': 1, 'of': 19},
#  'waking': {'in': 1, 'up': 4},
#  'working': {'hard': 2, 'man': 8, 'yes': 1},
#  'deep': {'down': 1, 'in': 4, 'inside': 1, 'tan': 1},
#  'pantomime': {'\n': 1},
#  'soaring': {'doves': 2},
#  'true': {'\n': 4},
#  'lies': {'\n': 1, 'and': 1, 'but': 1, 'in': 2, 'to': 1},
#  'unto': {'the': 1},
#  'son': {'\n': 1, 'of': 13},
#  'fold': {'\n': 1},
#  'salvation': {'\n': 1},
#  "we'll": {'be': 1, 'cry': 1, 'make': 4, 'never': 1, 'take': 4, 'watch': 2},
#  'sight': {'\n': 1},
#  'grows': {'into': 1},
#  'chchch': {'cherry': 1},
#  "that's": {'a': 2,
#   'all': 8,
#   'how': 1,
#   'in': 1,
#   'learned': 1,
#   'never': 3,
#   'nice': 1,
#   'not': 3,
#   'on': 1,
#   'the': 2,
#   'what': 2,
#   'why': 1},
#  'beckoning': {'\n': 1},
#  'welcome': {'here': 6, 'to': 8},
#  'names': {'\n': 1, 'upon': 1},
#  'flashing': {'lights': 1},
#  'pastor': {'preacher': 1},
#  'round': {'\n': 8, 'and': 6},
#  'sink': {'into': 1},
#  'bright': {'\n': 2, 'i': 1, 'light': 1, 'they': 1},
#  'cunningly': {'estranging': 1},
#  'getting': {'stronger': 3, 'thinner': 1},
#  'each': {'other': 8, "other's": 2},
#  'wrath': {'of': 6},
#  'gather': {'all': 1},
#  'shout': {'it': 2},
#  'thank': {'you': 3},
#  'settled': {'up': 1},
#  'live': {'a': 2,
#   'forgotten': 1,
#   'like': 2,
#   'my': 3,
#   'on': 1,
#   'the': 4,
#   'tonight': 3,
#   'until': 3,
#   'with': 3,
#   'young': 2,
#   'your': 2},
#  "containin'": {'\n': 1},
#  'steady': {'\n': 1},
#  'the': {'\n': 8,
#   "'x'": 1,
#   'academy': 1,
#   'adrenaline': 6,
#   'afternoon': 1,
#   'air': 3,
#   'apocalypse': 2,
#   'attic': 1,
#   'baby': 1,
#   'back': 1,
#   'backseat': 1,
#   'basics': 1,
#   'battle': 6,
#   'bay': 2,
#   'beast': 1,
#   'beauty': 1,
#   'bed': 1,
#   'best': 2,
#   'birds': 1,
#   'blood': 2,
#   "blood's": 1,
#   'blooded': 1,
#   'bloodwood': 1,
#   'body': 2,
#   'books': 1,
#   'both': 6,
#   'bottom': 2,
#   'box': 2,
#   'brain': 2,
#   'breathing': 1,
#   'brightest': 1,
#   'brim': 2,
#   'brink': 1,
#   'bullets': 3,
#   'bush': 4,
#   'caesar': 1,
#   'candlelight': 1,
#   'cards': 1,
#   'casing': 1,
#   'cellar': 1,
#   'center': 5,
#   'chains': 3,
#   'chemicals': 1,
#   'children': 1,
#   'city': 11,
#   'cloud': 1,
#   'cockatoos': 1,
#   'color': 5,
#   'colorless': 1,
#   'colors': 8,
#   'commodities': 1,
#   'confidence': 2,
#   'constitution': 1,
#   'coolers': 1,
#   'country': 1,
#   'course': 1,
#   'cries': 1,
#   'crippled': 1,
#   'crosshair': 1,
#   'crowd': 2,
#   'current': 2,
#   "current's": 4,
#   'curse': 1,
#   'curses': 1,
#   'curtain': 3,
#   "curtain's": 1,
#   'curtains': 1,
#   'daily': 1,
#   'dark': 8,
#   'darkest': 1,
#   'darkness': 11,
#   'day': 1,
#   'days': 5,
#   'dead': 2,
#   'deepest': 1,
#   'demonstrated': 1,
#   'desert': 1,
#   'dirt': 5,
#   'distance': 2,
#   'door': 6,
#   'dot': 2,
#   'down': 1,
#   'dream': 3,
#   'easy': 1,
#   'edge': 6,
#   'emptiness': 1,
#   'end': 4,
#   'ending': 2,
#   'entry': 1,
#   'essence': 1,
#   'evening': 1,
#   'eye': 1,
#   'eyes': 6,
#   'face': 1,
#   'faces': 1,
#   'faintest': 1,
#   'faithful': 1,
#   'fall': 4,
#   'falling': 1,
#   'false': 2,
#   'fast': 4,
#   'feeling': 2,
#   'few': 1,
#   'field': 3,
#   'fighting': 1,
#   'finest': 1,
#   'fire': 1,
#   'first': 1,
#   'flame': 1,
#   'flooded': 1,
#   'floor': 5,
#   'flowers': 4,
#   'forest': 2,
#   'fourth': 1,
#   'foyer': 1,
#   'friction': 6,
#   'future': 1,
#   'giver': 6,
#   'glam': 1,
#   'glasses': 1,
#   'glitz': 1,
#   'globe': 1,
#   'glory': 1,
#   'golden': 1,
#   'good': 1,
#   'government': 1,
#   'grace': 1,
#   'grass': 1,
#   'grave': 1,
#   'grayest': 4,
#   "greeter's": 1,
#   'ground': 18,
#   'hallways': 1,
#   'hands': 8,
#   'hate': 1,
#   'headlights': 3,
#   'heart': 1,
#   'heat': 2,
#   'heckle': 1,
#   'heights': 3,
#   'highest': 1,
#   'highway': 1,
#   'home': 2,
#   'hopes': 1,
#   'hour': 1,
#   'institution': 1,
#   'interest': 1,
#   'join': 1,
#   'judges': 1,
#   'jury': 1,
#   "king's": 1,
#   'kiss': 1,
#   'kitchen': 4,
#   'labor': 1,
#   'land': 3,
#   'last': 10,
#   'latest': 1,
#   'lead': 1,
#   'leap': 1,
#   'least': 1,
#   'leaves': 3,
#   'left': 1,
#   'less': 3,
#   'lie': 1,
#   'life': 1,
#   'light': 2,
#   'lights': 5,
#   'line': 8,
#   'lines': 4,
#   'list': 1,
#   'lives': 1,
#   'lonely': 2,
#   'love': 1,
#   "lover's": 1,
#   'low': 3,
#   'man': 16,
#   'masquerade': 1,
#   'masses': 2,
#   'master': 2,
#   'mean': 2,
#   'meantime': 1,
#   'men': 3,
#   'mess': 2,
#   'middle': 8,
#   'midnight': 1,
#   'midwest': 1,
#   'mind': 2,
#   'mist': 1,
#   'mistakes': 1,
#   'mold': 1,
#   'money': 10,
#   "money's": 2,
#   'moon': 5,
#   'moonlight': 2,
#   'more': 9,
#   'morning': 3,
#   'most': 1,
#   'mountain': 1,
#   'mouth': 19,
#   'mush': 3,
#   'names': 1,
#   'needle': 1,
#   'new': 12,
#   'night': 6,
#   'noise': 1,
#   'noises': 1,
#   'nose': 1,
#   'nothings': 1,
#   'ocean': 2,
#   'one': 34,
#   'ones': 4,
#   'only': 5,
#   'opera': 1,
#   'other': 3,
#   'others': 1,
#   'pain': 5,
#   'palms': 4,
#   'parenthetical': 1,
#   'past': 2,
#   'path': 4,
#   'pawn': 1,
#   'pay': 2,
#   'people': 12,
#   'photographs': 3,
#   'pictures': 1,
#   'pit': 1,
#   'place': 1,
#   'places': 3,
#   'plan': 1,
#   'plane': 3,
#   'pressure': 3,
#   'prettiest': 1,
#   'pretty': 1,
#   'prime': 1,
#   'prison': 2,
#   'prisoners': 2,
#   'prodigal': 1,
#   'puzzle': 2,
#   'radio': 2,
#   'rags': 1,
#   'rain': 4,
#   'real': 1,
#   'reason': 3,
#   'records': 1,
#   'rent': 4,
#   'rest': 3,
#   'rhinestones': 1,
#   "rifle's": 1,
#   'right': 1,
#   'risk': 1,
#   'river': 37,
#   'road': 3,
#   'roaring': 1,
#   'rock': 4,
#   'rush': 2,
#   'sail': 1,
#   'saints': 1,
#   'same': 26,
#   'sand': 1,
#   'sea': 1,
#   'season': 2,
#   'seasons': 1,
#   'second': 3,
#   'selfish': 1,
#   'setting': 1,
#   'shackle': 1,
#   'shadows': 3,
#   'shirt': 1,
#   'short': 6,
#   'side': 4,
#   'silence': 1,
#   'silver': 1,
#   'sinners': 1,
#   'sins': 1,
#   'sky': 8,
#   'slip': 2,
#   'small': 1,
#   'snow': 1,
#   'soil': 1,
#   'soldier': 3,
#   'soul': 1,
#   'spotlight': 2,
#   'stage': 1,
#   'stars': 9,
#   'start': 1,
#   'static': 1,
#   'step': 1,
#   'stone': 2,
#   'storm': 2,
#   'strangers': 1,
#   'strangest': 1,
#   'stray': 1,
#   'street': 4,
#   'streets': 1,
#   'summertime': 3,
#   'sun': 12,
#   'surface': 1,
#   'system': 2,
#   'tables': 2,
#   'talk': 4,
#   'tallest': 2,
#   'tasteless': 1,
#   'things': 17,
#   'thunder': 20,
#   'tier': 1,
#   'time': 13,
#   'tin': 2,
#   'tip': 1,
#   'tomb': 1,
#   'top': 22,
#   'towers': 1,
#   'town': 5,
#   'trees': 2,
#   'truth': 6,
#   "tunnel's": 1,
#   'underdog': 12,
#   'unknown': 1,
#   'valley': 1,
#   'veins': 1,
#   'very': 1,
#   'vices': 1,
#   'victim': 1,
#   'view': 2,
#   'vision': 2,
#   'visual': 1,
#   'void': 3,
#   'wall': 2,
#   'war': 1,
#   'warmest': 1,
#   'warriors': 6,
#   'water': 2,
#   "water's": 1,
#   'waters': 1,
#   'waves': 1,
#   'way': 4,
#   'weekend': 1,
#   'westcoast': 1,
#   'western': 4,
#   'whispers': 1,
#   'wind': 5,
#   'wire': 11,
#   'wolves': 1,
#   'words': 2,
#   'work': 1,
#   'worker': 3,
#   'working': 8,
#   'world': 37,
#   'worst': 3,
#   'wrath': 6,
#   'wrist': 1,
#   'writing': 1,
#   'year': 1,
#   'years': 2,
#   'yellow': 2},
#  'telegram': {'i': 1},
#  'creeping': {'up': 1},
#  'limb': {'\n': 2},
#  'breathing': {'\n': 1, 'heavy': 1, 'in': 2, 'until': 1, 'voices': 1},
#  'system': {'\n': 1, 'a': 1},
#  'ask': {'me': 4, 'us': 1},
#  'astray': {'fade': 1},
#  'scared': {'\n': 2, 'of': 1},
#  'unaware': {'of': 1},
#  'raise': {'\n': 1, 'my': 1},
#  'know': {'\n': 34,
#   'a': 2,
#   'all': 1,
#   'anything': 1,
#   'do': 4,
#   'every': 2,
#   'i': 5,
#   "i'm": 12,
#   'it': 2,
#   "it's": 14,
#   'its': 2,
#   'knowohohoh': 1,
#   'me': 2,
#   'my': 1,
#   'our': 1,
#   'quite': 1,
#   'that': 10,
#   'the': 4,
#   'to': 2,
#   "we're": 4,
#   'when': 1,
#   'where': 3,
#   'which': 1,
#   'why': 11,
#   'you': 5,
#   "you're": 8},
#  'ba': {'boom': 2, 'doom': 4},
#  'draw': {'a': 1, 'the': 3, 'to': 1},
#  'nobody': {'\n': 2, 'can': 10, 'else': 6, 'hear': 1},
#  'attic': {'\n': 1},
#  'brought': {'the': 1, 'your': 1},
#  'studied': {'bliss': 1},
#  'rather': {'be': 1, 'die': 1, 'stay': 5},
#  'edge': {'\n': 1, 'of': 6},
#  'yet': {'a': 1, "i'm": 1, 'to': 1},
#  'means': {'of': 2},
#  'four': {'flights': 1, 'wheels': 1},
#  'yeehoo': {'\n': 1},
#  'fly': {'\n': 1, 'by': 1, 'me': 1, 'oh': 3},
#  'dance': {'\n': 3, 'when': 6, 'with': 7},
#  'waters': {'\n': 1, 'of': 1},
#  'stitched': {'into': 1},
#  'bourbon': {'streets': 1},
#  'kiss': {'and': 2, 'goodbye': 1, 'lights': 2, 'of': 1},
#  'center': {'of': 3, 'sin': 2},
#  'shirt': {'that': 1},
#  'asking': {'why': 1},
#  'note': {'\n': 1},
#  'epoxy': {'to': 1},
#  'she': {'asked': 1,
#   'barely': 4,
#   'brings': 1,
#   'gave': 1,
#   'goes': 2,
#   'knew': 1,
#   'left': 1,
#   'must': 2,
#   'needed': 1,
#   'was': 1,
#   'will': 1,
#   'would': 1},
#  'yessir': {'not': 1},
#  'version': {'\n': 1},
#  'photograph': {'of': 2},
#  'sign': {'\n': 2, 'give': 2, 'our': 2, 'sweep': 1, 'the': 1, 'we': 2},
#  'bet': {'my': 21},
#  'his': {'\n': 1, 'bags': 1, 'cellphone': 1, 'courage': 1, 'fears': 1},
#  'ne': {'réponds': 1},
#  'spirit': {'never': 1, 'to': 1, 'up': 1},
#  'disgrace': {'a': 1},
#  'cry': {'\n': 17, "'till": 2, 'but': 1, 'for': 3, 'mother': 1, 'tonight': 1},
#  'hypocritical': {'egotistical': 1},
#  'check': {'\n': 2},
#  'fed': {'\n': 1},
#  'matter': {'\n': 3,
#   'if': 15,
#   'it': 2,
#   'most': 1,
#   'no': 1,
#   'of': 4,
#   'the': 1,
#   'what': 3},
#  'become': {'of': 3},
#  'determine': {'\n': 1},
#  'dada': {'\n': 6},
#  'midnight': {'hour': 2, 'talker': 1},
#  'very': {'last': 1},
#  'provides': {'us': 1},
#  'fear': {'\n': 2, 'is': 2, 'of': 1},
#  'highway': {'\n': 1},
#  'colorless': {'sunrise': 1},
#  'dismoi': {'pourquoi': 13},
#  'deepest': {'rivers': 1},
#  'stray': {'\n': 2, 'the': 2},
#  'ouh': {'la': 1},
#  'dismissed': {'it': 1},
#  'no': {'\n': 8,
#   'deceiving': 1,
#   'ending': 1,
#   'enemies': 1,
#   'excuses': 2,
#   'faith': 3,
#   'forgiveness': 2,
#   'i': 1,
#   'innocence': 1,
#   'lies': 1,
#   'longer': 1,
#   'matter': 5,
#   'more': 4,
#   'need': 1,
#   'noohohoh': 2,
#   'not': 1,
#   'oh': 1,
#   'one': 3,
#   'place': 1,
#   'privilege': 1,
#   'reason': 1,
#   'sign': 1,
#   'these': 2,
#   'time': 4,
#   'tomorrow': 4,
#   'trouble': 24,
#   'we': 1,
#   'words': 1},
#  'commissions': {'of': 1},
#  'backseat': {'\n': 1},
#  'around': {'\n': 13,
#   'and': 6,
#   'here': 4,
#   'i': 1,
#   "i've": 1,
#   'the': 3,
#   'to': 1},
#  'books': {'and': 1},
#  'older': {'\n': 4, 'and': 2, 'than': 3},
#  'lived': {'ebbing': 2},
#  'over': {'\n': 45,
#   'again': 2,
#   'and': 4,
#   'me': 1,
#   'over': 5,
#   'twice': 4,
#   'unless': 3,
#   'you': 2,
#   'your': 1},
#  'strong': {'\n': 3, 'and': 1, 'ease': 3},
#  'stress': {'lines': 1},
#  'why': {'\n': 13, "can't": 1, 'cant': 2, "don't": 4, 'i': 6, 'im': 1},
#  'write': {'my': 2},
#  'boom': {'\n': 5, 'ba': 4},
#  'captivating': {'every': 3},
#  'forgiven': {'unless': 4},
#  'rubber': {'ghost': 1},
#  'tops': {'time': 3},
#  'excuses': {'\n': 2},
#  'sweep': {'me': 1},
#  'crows': {'\n': 2},
#  "empire's": {'fall': 1},
#  'self': {'indication': 1, 'invitation': 1},
#  'snow': {'\n': 1},
#  'lost': {'\n': 3,
#   'at': 2,
#   'cannot': 1,
#   'cause': 12,
#   'in': 4,
#   'lost': 4,
#   'my': 1,
#   'myself': 1},
#  'smash': {'and': 1},
#  'together': {'voilà': 1},
#  'should': {'have': 1, 'just': 2},
#  'ones': {'around': 1, 'that': 1, 'up': 1, 'we': 1},
#  '\n': {'': 140,
#   "'cause": 35,
#   'a': 27,
#   'about': 1,
#   'above': 1,
#   'after': 2,
#   'again': 3,
#   'ah': 3,
#   'all': 45,
#   'alright': 1,
#   'always': 16,
#   'am': 4,
#   'america': 9,
#   'an': 2,
#   'and': 194,
#   'another': 12,
#   'anything': 1,
#   'anywhere': 1,
#   'are': 4,
#   'arrange': 1,
#   'as': 4,
#   'asking': 1,
#   'astrology': 1,
#   'at': 9,
#   'auntie': 1,
#   'baby': 17,
#   "baby's": 2,
#   'back': 7,
#   'bail': 2,
#   'bang': 3,
#   'because': 17,
#   'been': 18,
#   'before': 7,
#   'being': 1,
#   'belief': 1,
#   'believe': 12,
#   'below': 1,
#   'beside': 1,
#   'better': 4,
#   'between': 1,
#   'beyond': 1,
#   'bird': 1,
#   'blessings': 1,
#   'blood': 1,
#   'boom': 3,
#   'boots': 1,
#   'bourbon': 1,
#   'boy': 2,
#   'break': 10,
#   'bring': 1,
#   'broken': 2,
#   'brothers': 2,
#   'bubbling': 1,
#   'building': 2,
#   'but': 114,
#   'by': 3,
#   'can': 22,
#   "can't": 8,
#   'cant': 3,
#   'capable': 1,
#   'captivating': 3,
#   'casually': 1,
#   'caught': 3,
#   'cause': 16,
#   'ce': 1,
#   'cha': 6,
#   'chchchchchch': 1,
#   'checking': 2,
#   'cherry': 2,
#   'chickaboom': 1,
#   'chorus': 2,
#   'circling': 4,
#   'clenched': 1,
#   'close': 1,
#   'closing': 1,
#   'clouds': 1,
#   'cold': 1,
#   'collapsing': 1,
#   'come': 10,
#   'coming': 4,
#   'count': 7,
#   'counting': 1,
#   'cover': 6,
#   'cross': 1,
#   'crying': 2,
#   'curse': 3,
#   'curt': 1,
#   'da': 6,
#   'dadada': 6,
#   'dancing': 9,
#   'dangerous': 3,
#   'ddddid': 2,
#   'death': 1,
#   'deep': 2,
#   'desolation': 2,
#   'destination': 1,
#   'determination': 1,
#   'did': 1,
#   'dinner': 1,
#   'dismoi': 11,
#   'do': 7,
#   'doesnt': 15,
#   "don't": 34,
#   'dont': 10,
#   'down': 3,
#   'draw': 1,
#   'dreaming': 1,
#   'drive': 3,
#   'drugs': 1,
#   'dying': 1,
#   'early': 4,
#   'elastic': 1,
#   'emma': 13,
#   'enemies': 1,
#   'enough': 3,
#   'et': 1,
#   'even': 4,
#   'every': 26,
#   'everybody': 5,
#   'everyone': 2,
#   'everything': 23,
#   'exciting': 2,
#   'exhilarating': 3,
#   'face': 1,
#   'fall': 1,
#   'falling': 2,
#   'far': 1,
#   'farewell': 1,
#   'fate': 1,
#   'father': 4,
#   'fear': 1,
#   'february': 1,
#   'feel': 8,
#   'feelings': 2,
#   'fills': 1,
#   'find': 1,
#   'first': 2,
#   'fit': 1,
#   'flies': 1,
#   'flipping': 4,
#   'fly': 1,
#   'fog': 1,
#   'follow': 2,
#   'for': 13,
#   'forgive': 2,
#   'four': 1,
#   'from': 15,
#   'gather': 1,
#   'get': 8,
#   'give': 11,
#   'glory': 4,
#   'go': 5,
#   'gold': 9,
#   'good': 3,
#   'goodbye': 4,
#   'got': 1,
#   'grew': 1,
#   'guarding': 1,
#   'guitar': 1,
#   'ha': 2,
#   'had': 1,
#   'hang': 2,
#   'has': 1,
#   'have': 1,
#   'he': 3,
#   "he'll": 2,
#   "he's": 3,
#   "heater's": 1,
#   'heaven': 2,
#   'hell': 11,
#   'help': 1,
#   'here': 10,
#   "here's": 15,
#   'hey': 45,
#   'hold': 6,
#   'holden': 1,
#   'holding': 1,
#   'holy': 2,
#   'home': 1,
#   'hopefully': 2,
#   'hoping': 2,
#   'hotter': 1,
#   'how': 19,
#   'however': 4,
#   'hustle': 1,
#   'hypocritical': 1,
#   'i': 380,
#   "i'd": 7,
#   "i'll": 22,
#   "i'm": 159,
#   "i'ma": 2,
#   "i'mma": 6,
#   "i've": 51,
#   'if': 47,
#   'im': 43,
#   'imagine': 2,
#   'in': 18,
#   'inhibited': 2,
#   'innocence': 2,
#   'innocent': 5,
#   'instead': 1,
#   'interlude': 1,
#   'into': 1,
#   'is': 40,
#   'it': 37,
#   "it's": 96,
#   'its': 12,
#   'ive': 5,
#   'jackie': 1,
#   'jealousy': 1,
#   'join': 7,
#   'just': 44,
#   'kids': 1,
#   'kimi': 4,
#   'kind': 4,
#   'kinda': 1,
#   'king': 2,
#   'kiss': 2,
#   'knees': 1,
#   'know': 1,
#   'knowing': 1,
#   'la': 2,
#   'last': 1,
#   'late': 1,
#   'laughter': 2,
#   'lay': 4,
#   'leave': 14,
#   "leavin'": 2,
#   'lesser': 4,
#   'let': 23,
#   "let's": 5,
#   'letter': 2,
#   'letusbefearless': 1,
#   'life': 2,
#   'lift': 6,
#   'lightning': 9,
#   'like': 8,
#   'listen': 1,
#   'live': 1,
#   'living': 9,
#   'loneliness': 1,
#   'look': 15,
#   'looking': 6,
#   'lost': 1,
#   'love': 14,
#   "love's": 1,
#   'loving': 1,
#   'low': 2,
#   'make': 1,
#   'makes': 1,
#   'mama': 1,
#   'man': 1,
#   'maybe': 12,
#   'melodic': 1,
#   'mmmmouth': 12,
#   'mocking': 1,
#   'monday': 1,
#   'most': 1,
#   'movement': 1,
#   'moving': 1,
#   'my': 23,
#   'negative': 1,
#   'never': 1,
#   'next': 6,
#   'nice': 1,
#   'no': 21,
#   'nobody': 15,
#   'not': 10,
#   'nothing': 13,
#   'now': 16,
#   'of': 4,
#   'off': 2,
#   'oh': 193,
#   'ohh': 3,
#   'older': 1,
#   'one': 11,
#   'only': 5,
#   'ooh': 5,
#   'oooh': 1,
#   'open': 10,
#   'or': 3,
#   'our': 1,
#   'out': 2,
#   'outro': 1,
#   'over': 2,
#   'overlook': 1,
#   'pace': 2,
#   'packing': 1,
#   'pain': 12,
#   'paint': 1,
#   'part': 1,
#   'passion': 3,
#   'pastor': 1,
#   'paying': 5,
#   'petty': 1,
#   'picking': 1,
#   'piece': 1,
#   'pistol': 3,
#   'please': 7,
#   'pledge': 1,
#   'pray': 3,
#   'probably': 1,
#   'promise': 1,
#   'promises': 1,
#   'pull': 2,
#   'purifying': 1,
#   'pushing': 2,
#   'put': 1,
#   'quicker': 1,
#   'reach': 4,
#   'ready': 9,
#   'remember': 2,
#   'resolutions': 4,
#   'right': 5,
#   'rise': 8,
#   'rock': 6,
#   'round': 6,
#   'run': 3,
#   "runnin'": 1,
#   'running': 1,
#   'say': 1,
#   'screaming': 1,
#   'searching': 1,
#   'second': 1,
#   'see': 1,
#   'seeing': 1,
#   'send': 1,
#   'set': 1,
#   'shadow': 1,
#   'shake': 10,
#   'shaking': 1,
#   'she': 9,
#   'shooting': 1,
#   'show': 3,
#   'shuffle': 1,
#   'silence': 1,
#   'singing': 4,
#   'sink': 1,
#   'sit': 2,
#   'sitting': 1,
#   'sixteen': 1,
#   'slip': 1,
#   'so': 86,
#   'soaring': 2,
#   'soars': 1,
#   'some': 16,
#   'somehow': 1,
#   'something': 1,
#   'sooner': 2,
#   'speak': 6,
#   'speaking': 2,
#   'staining': 1,
#   'stand': 2,
#   'staring': 1,
#   'stars': 4,
#   'statues': 1,
#   'stay': 12,
#   'steam': 1,
#   'step': 1,
#   'stitched': 1,
#   'stop': 7,
#   'stopped': 1,
#   'story': 1,
#   'stress': 1,
#   'suppressed': 1,
#   'take': 34,
#   'takes': 1,
#   'taking': 3,
#   'talking': 2,
#   'tears': 1,
#   'tell': 12,
#   'telling': 1,
#   'terrorism': 1,
#   'than': 1,
#   'thank': 1,
#   'that': 39,
#   "that's": 9,
#   'the': 55,
#   'then': 3,
#   'there': 2,
#   "there'll": 2,
#   "there's": 10,
#   'theres': 13,
#   'these': 9,
#   'they': 34,
#   'things': 1,
#   'third': 1,
#   'this': 36,
#   'those': 5,
#   'though': 4,
#   'through': 2,
#   "throwin'": 1,
#   'thunder': 12,
#   'tie': 1,
#   'till': 9,
#   'timber': 2,
#   'time': 8,
#   'to': 66,
#   'tokyo': 9,
#   'tonight': 1,
#   'too': 2,
#   'took': 1,
#   'tooookyyoooooooo': 2,
#   'trace': 1,
#   'trading': 1,
#   'tripping': 1,
#   'trouble': 4,
#   'try': 2,
#   'tu': 1,
#   'turn': 3,
#   'twenty': 7,
#   'typically': 3,
#   'undercover': 1,
#   'until': 1,
#   'up': 4,
#   'upon': 1,
#   'wait': 8,
#   'waiting': 6,
#   'walking': 7,
#   'wanna': 4,
#   'want': 1,
#   'was': 1,
#   'washed': 1,
#   'waste': 2,
#   'watch': 2,
#   'water': 1,
#   'we': 83,
#   "we'd": 2,
#   "we'll": 7,
#   "we're": 16,
#   "we've": 14,
#   'welcome': 8,
#   'well': 11,
#   'what': 30,
#   "what's": 1,
#   'whatever': 8,
#   'when': 58,
#   'whenever': 6,
#   'where': 20,
#   'while': 6,
#   'whip': 2,
#   'who': 22,
#   'whoa': 11,
#   'whoaoh': 2,
#   'why': 7,
#   'will': 5,
#   'wise': 1,
#   'with': 14,
#   'without': 1,
#   'woah': 7,
#   'woahohoh': 4,
#   'woman': 1,
#   'wonderful': 2,
#   'wont': 4,
#   'word': 2,
#   'working': 1,
#   'would': 5,
#   "wouldn't": 2,
#   'writing': 1,
#   'x': 5,
#   'yeah': 7,
#   'yesterday': 3,
#   'you': 102,
#   "you'd": 3,
#   "you'll": 10,
#   "you're": 24,
#   "you've": 19,
#   'your': 27,
#   'youre': 1},
#  'innocent': {'considering': 5},
#  'eyes': {'\n': 22,
#   'and': 2,
#   'are': 8,
#   'for': 1,
#   'i': 1,
#   'look': 1,
#   'of': 1,
#   'open': 2,
#   'shut': 5,
#   'so': 1,
#   'that': 4,
#   'they': 3,
#   "they're": 4,
#   'to': 4,
#   'tonight': 2},
#  "blood's": {'run': 1},
#  'wolves': {'all': 1},
#  'leaving': {'\n': 4, 'but': 1},
#  'meeting': {'strangers': 4},
#  'keep': {'calling': 1,
#   'coming': 3,
#   'falling': 8,
#   'getting': 1,
#   'living': 1,
#   'me': 1,
#   'on': 4,
#   'pushing': 2,
#   "sayin'": 2,
#   'to': 2,
#   "tryin'": 1,
#   'trying': 2,
#   'us': 1,
#   'your': 4},
#  'carnivals': {'\n': 1},
#  'carfilled': {'streets': 1},
#  'by': {'\n': 2,
#   'a': 3,
#   'fiction': 2,
#   'hope': 1,
#   'it': 1,
#   'me': 1,
#   'my': 4,
#   'ourselves': 1,
#   'that': 6,
#   'the': 7},
#  'purifying': {'all': 1},
#  'seconds': {'\n': 3},
#  'satisfied': {'\n': 2},
#  'asleep': {'\n': 4, 'i': 2},
#  'clearly': {'\n': 4, 'i': 6, 'what': 2},
#  'stones': {'at': 1},
#  'morning': {'\n': 3,
#   'dew': 1,
#   'light': 1,
#   'my': 1,
#   'myself': 1,
#   'take': 1,
#   'wake': 1},
#  "i'm": {'a': 32,
#   'alkaline': 1,
#   'all': 1,
#   'alone': 6,
#   'alright': 1,
#   'always': 1,
#   'an': 2,
#   'anxious': 1,
#   'away': 1,
#   'begging': 1,
#   'bleeding': 7,
#   'blessed': 1,
#   'breaking': 4,
#   'breathing': 2,
#   'broken': 2,
#   'bursting': 1,
#   'calling': 6,
#   'coming': 11,
#   'destined': 1,
#   'different': 1,
#   'done': 2,
#   'dreaming': 1,
#   'dying': 1,
#   'easy': 1,
#   'falling': 6,
#   'far': 3,
#   'feeling': 4,
#   'fine': 1,
#   'fired': 1,
#   'foolish': 1,
#   'for': 13,
#   'fueled': 1,
#   'gonna': 28,
#   'growing': 1,
#   'halfdiseased': 1,
#   'headed': 1,
#   'here': 4,
#   "holdin'": 1,
#   'hoping': 3,
#   'in': 3,
#   'just': 34,
#   'keeping': 1,
#   'leaving': 2,
#   'living': 1,
#   'lonely': 1,
#   "lookin'": 2,
#   'losing': 1,
#   'lost': 2,
#   'nervous': 1,
#   'never': 6,
#   'not': 9,
#   'old': 1,
#   'on': 13,
#   'only': 5,
#   'overboard': 1,
#   'pacing': 2,
#   'proud': 1,
#   'radioactive': 6,
#   'ready': 11,
#   "runnin'": 1,
#   'selfassured': 1,
#   'selfdestructive': 1,
#   'smiling': 1,
#   'so': 10,
#   'sorry': 11,
#   'standing': 1,
#   'staring': 1,
#   'starting': 1,
#   'strobing': 1,
#   'stuck': 1,
#   'such': 1,
#   'supposed': 2,
#   "takin'": 1,
#   'taking': 3,
#   'telling': 1,
#   'the': 6,
#   'thinking': 2,
#   'tired': 1,
#   'trying': 6,
#   'waiting': 1,
#   'waking': 4,
#   "wishin'": 3,
#   'with': 1,
#   'working': 1,
#   'wrong': 2},
#  'changed': {'\n': 2},
#  'headed': {'for': 1, 'towards': 1},
#  'im': {'bleeding': 12,
#   'cursed': 2,
#   'doing': 4,
#   'drowned': 1,
#   'drowning': 1,
#   'dying': 2,
#   'giving': 12,
#   'going': 9,
#   'here': 1,
#   'just': 1,
#   'left': 1,
#   'living': 4,
#   'not': 3,
#   "playin'": 4,
#   'ready': 4,
#   'right': 1,
#   'short': 1},
#  'kintore': {'east': 1},
#  'shoulders': {'tight': 1},
#  'alibi': {'\n': 1},
#  'tooookyyoooooooo': {'\n': 2},
#  'trying': {'hard': 3, 'not': 6, 'to': 4},
#  'brush': {'in': 1},
#  'hundred': {'miles': 4, 'more': 4},
#  'friends': {'\n': 2, 'all': 1, 'are': 6},
#  'knees': {'\n': 2, 'in': 1, 'oh': 2},
#  'sense': {'\n': 3, 'of': 2},
#  'brain': {'\n': 1, 'just': 2},
#  'deciding': {'\n': 4},
#  'haver': {'hey': 1},
#  'warmest': {'night': 1},
#  'girl': {'\n': 1, 'and': 1, 'in': 1, 'with': 3},
#  'woven': {'in': 1},
#  'give': {'\n': 5,
#   'all': 1,
#   'and': 5,
#   'disgrace': 1,
#   'her': 1,
#   'him': 1,
#   'it': 21,
#   'me': 24,
#   'that': 1,
#   'to': 1,
#   'up': 11,
#   'you': 4},
#  'heard': {'\n': 2, 'has': 1},
#  'stole': {'my': 1},
#  'resistance': {'\n': 1},
#  'nights': {'\n': 3, 'cold': 1, 'i': 2, 'that': 3, 'we': 1},
#  'escaping': {'the': 1},
#  'product': {'of': 2},
#  'debris': {'my': 1},
#  'jury': {'stole': 1},
#  'straight': {'\n': 5, 'from': 1},
#  'mention': {'\n': 6},
#  'old': {'\n': 4,
#   'and': 1,
#   'for': 3,
#   'hands': 2,
#   'labels': 1,
#   'life': 1,
#   'plans': 2,
#   'stories': 4,
#   'tradition': 2,
#   'well': 1,
#   'with': 1},
#  'finest': {'of': 1},
#  'upon': {'my': 2, 'the': 2, 'your': 2},
#  'liked': {'that': 1},
#  'nepotist': {'\n': 1},
#  'reckless': {'mistake': 1},
#  'embrace': {'it': 1},
#  'western': {'desert': 1, 'sea': 1, 'train': 2},
#  'makes': {'me': 1},
#  'box': {'\n': 1, 'fit': 1},
#  'out': {'\n': 18,
#   'alive': 1,
#   'all': 1,
#   'and': 4,
#   'at': 4,
#   'but': 1,
#   'by': 1,
#   'down': 8,
#   'for': 12,
#   'here': 1,
#   "i'm": 1,
#   'in': 1,
#   'into': 1,
#   'my': 1,
#   'of': 11,
#   'on': 2,
#   'quick': 1,
#   'sing': 3,
#   'the': 1,
#   'to': 7,
#   'well': 1,
#   'when': 1,
#   'where': 1,
#   'with': 1,
#   'yeah': 1},
#  'trees': {'begin': 1, 'they': 1},
#  "current's": {'coming': 4},
#  'rent': {'\n': 2, 'now': 2},
#  'tattered': {'window': 2},
#  'took': {'a': 3, 'the': 5, 'to': 1, 'your': 2},
#  'sudden': {'attraction': 1},
#  'politics': {'and': 1},
#  'run': {'\n': 6,
#   'and': 2,
#   'away': 6,
#   'for': 1,
#   'i': 2,
#   'me': 2,
#   'stale': 1,
#   'through': 1,
#   'to': 3,
#   'who': 1},
#  'mao': {'\n': 1},
#  'wrecks': {'and': 1},
#  'built': {'this': 6},
#  'everybody': {'\n': 2,
#   'blow': 2,
#   'circling': 1,
#   'else': 1,
#   'hoping': 1,
#   'needs': 1,
#   'praying': 1,
#   'says': 3,
#   'sees': 3,
#   'tell': 2,
#   'waiting': 1},
#  "baby's": {'got': 2},
#  'crowd': {'\n': 2},
#  'mean': {'\n': 3, 'by': 2, 'it': 2, 'time': 2, 'to': 2},
#  'must': {'laugh': 1, 'smile': 1},
#  'lesser': {'of': 4},
#  'cannot': {'be': 1, 'breathe': 1},
#  'mystery': {'\n': 2},
#  "he's": {'got': 4, 'looking': 1, 'packed': 1, 'up': 1},
#  'uncertainty': {'\n': 1},
#  'nowhere': {'\n': 2, 'we': 1},
#  'cease': {'to': 2},
#  'itd': {'be': 1},
#  'anything': {'at': 2, 'but': 1, 'you': 1},
#  'mothers': {'woah': 1},
#  'heights': {'that': 3},
#  'free': {'\n': 3, 'again': 4, 'your': 1},
#  'religious': {'with': 1},
#  'number': {'\n': 2},
#  'crashing': {'down': 9},
#  'horse': {'\n': 2},
#  'pleading': {'near': 1},
#  'thief': {'\n': 6},
#  'tradition': {'\n': 2},
#  'desire': {'\n': 1},
#  'inhibited': {'limited': 2},
#  'seized': {'\n': 1},
#  'grab': {'your': 2},
#  'wars': {'across': 1},
#  'skin': {'\n': 4},
#  'with': {'a': 14,
#   'all': 3,
#   'anyone': 1,
#   'certainty': 1,
#   'confidence': 3,
#   'empty': 3,
#   'everybody': 1,
#   'his': 1,
#   'hollering': 1,
#   'magnet': 1,
#   'me': 37,
#   'my': 4,
#   'myself': 2,
#   'no': 1,
#   'our': 1,
#   'the': 15,
#   'their': 3,
#   'time': 1,
#   'what': 2,
#   'you': 48,
#   'your': 1},
#  'leap': {'\n': 1},
#  'higher': {'\n': 11, 'elevation': 1, 'floors': 4, 'up': 3},
#  'corners': {'\n': 1},
#  'heckle': {'holding': 1},
#  'labels': {'\n': 1},
#  'pledge': {'allegiance': 1},
#  'loving': {'the': 1},
#  'nose': {'bleeds': 1},
#  'entities': {'to': 1},
#  'stubborn': {'as': 1},
#  'sounds': {'like': 8, 'you': 6},
#  'cleanse': {'in': 4},
#  'count': {'me': 5, 'my': 4, 'to': 1, 'your': 3},
#  'warriors': {'that': 6},
#  'wire': {'\n': 5, 'love': 6, 'wire': 10},
#  'penny': {'on': 1},
#  'strength': {'to': 7},
#  'paradigm': {'\n': 1},
#  'prime': {'of': 1},
#  'shoes': {'at': 1},
#  'chchchchchch': {'cherry': 1},
#  "heart's": {'turned': 1},
#  'wishing': {'\n': 4},
#  'gin': {'\n': 1},
#  'about': {'\n': 1, 'a': 2, 'destruction': 1, 'the': 3, 'time': 1},
#  'ran': {'along': 1},
#  'word': {'\n': 1, 'cause': 1, 'dream': 1, 'heart': 2, 'this': 1, 'upon': 2},
#  'smile': {'\n': 2, 'hey': 5, 'on': 1, 'she': 1},
#  'among': {'guys': 1},
#  'ascend': {'\n': 1},
#  "here's": {'to': 20},
#  'interlude': {'\n': 1},
#  'burn': {'\n': 1, 'down': 1, 'out': 1, 'so': 2, 'to': 3},
#  'hottie': {'with': 4},
#  'fill': {'\n': 1, 'the': 4, 'up': 4, 'your': 1},
#  'spend': {'\n': 8},
#  'shook': {'to': 1},
#  'cave': {"i'm": 1},
#  "lookin'": {'at': 1, 'effortless': 1, 'for': 2},
#  'martyrdom': {'\n': 1},
#  'passion': {'tops': 3},
#  'war': {'\n': 3, 'has': 1},
#  'coughing': {'on': 1},
#  'hand': {'\n': 6, 'on': 2, 'when': 1},
#  'can': {'\n': 5,
#   'assess': 1,
#   'atone': 1,
#   'attain': 1,
#   'attest': 1,
#   'barely': 1,
#   'be': 6,
#   'blame': 2,
#   'count': 1,
#   'do': 1,
#   'erase': 1,
#   'fake': 1,
#   'fight': 14,
#   'fill': 4,
#   'find': 2,
#   'give': 10,
#   'go': 1,
#   'hardly': 1,
#   'have': 1,
#   'hide': 1,
#   'i': 3,
#   'last': 2,
#   'leave': 1,
#   'let': 5,
#   'make': 1,
#   'never': 2,
#   'nobody': 1,
#   'reach': 1,
#   'save': 12,
#   'see': 18,
#   'show': 1,
#   'start': 8,
#   'stay': 3,
#   'take': 5,
#   'tell': 6,
#   'understand': 2,
#   'we': 22,
#   'you': 20},
#  'walked': {'a': 4, 'into': 1, 'that': 1},
#  'cage': {'man': 2},
#  'shine': {'in': 1, 'on': 1, 'so': 1},
#  'destiny': {'is': 4, 'sealed': 3},
#  'clutch': {'my': 1},
#  'body': {'\n': 5,
#   'and': 1,
#   'feeling': 1,
#   'into': 1,
#   'start': 3,
#   'through': 1},
#  'fallin': {'down': 1},
#  'now': {'\n': 43,
#   "don't": 6,
#   'get': 2,
#   'i': 4,
#   "i'm": 6,
#   "it's": 1,
#   'no': 2,
#   'oh': 12,
#   'or': 1,
#   'ready': 3,
#   'remember': 2,
#   'theyre': 1,
#   'unless': 1,
#   "we're": 2,
#   'will': 1,
#   'x': 2,
#   'you': 1},
#  'drive': {'i': 3, 'it': 3},
#  'selfassured': {'\n': 1},
#  'scheme': {'\n': 1},
#  'handcuff': {'\n': 2},
#  'burning': {'\n': 6},
#  'health': {'\n': 1},
#  'name': {'\n': 11, "'round": 1, 'after': 2, 'is': 5},
#  'message': {'from': 1},
#  'find': {'a': 7,
#   'is': 1,
#   'me': 2,
#   'my': 2,
#   'myself': 1,
#   'or': 1,
#   'their': 2,
#   'you': 6},
#  'ash': {'and': 1},
#  'die': {'\n': 15, 'happily': 1, 'old': 1, 'than': 1, 'tonight': 3},
#  'top': {'\n': 8, 'now': 2, 'of': 20, 'ohoh': 1, 'till': 3, 'with': 2},
#  'shadows': {'\n': 2, 'in': 1, 'on': 1},
#  'happily': {'and': 1},
#  'teeth': {'no': 1},
#  'precious': {'breath': 2, 'love': 1},
#  'hotter': {'than': 1},
#  'shimmy': {'and': 5},
#  'labor': {'of': 1},
#  'of': {"'em": 1,
#   'a': 23,
#   'all': 12,
#   'amsterdam': 2,
#   'anarchy': 1,
#   'ancients': 2,
#   'baggage': 2,
#   'being': 3,
#   'bigger': 1,
#   'boom': 4,
#   'breath': 1,
#   'business': 1,
#   'cards': 1,
#   'chairman': 1,
#   'clouded': 1,
#   'coke': 4,
#   'darkness': 1,
#   'death': 1,
#   'desire': 1,
#   'diamonds': 1,
#   'everything': 2,
#   'fail': 1,
#   'falling': 1,
#   'fear': 1,
#   'flashing': 1,
#   'gold': 1,
#   'greater': 1,
#   'greed': 2,
#   'hearts': 3,
#   'hell': 1,
#   'hire': 1,
#   'home': 1,
#   'it': 10,
#   'jealousy': 1,
#   'july': 1,
#   'life': 2,
#   'lights': 1,
#   'look': 4,
#   'love': 3,
#   'luck': 1,
#   'man': 1,
#   'me': 16,
#   'men': 2,
#   'mental': 1,
#   'mud': 1,
#   'muddy': 1,
#   'my': 7,
#   'night': 1,
#   'oh': 4,
#   'our': 3,
#   'out': 1,
#   'patience': 2,
#   'precious': 2,
#   'purpose': 1,
#   'red': 2,
#   'salvation': 1,
#   'sands': 1,
#   'sin': 8,
#   'sins': 1,
#   'smash': 1,
#   'something': 1,
#   'stone': 1,
#   'the': 93,
#   'thee': 1,
#   'this': 12,
#   'those': 1,
#   'time': 1,
#   'times': 2,
#   'touch': 1,
#   'trust': 2,
#   'two': 4,
#   'us': 7,
#   'view': 1,
#   'vindication': 1,
#   'wealth': 1,
#   'who': 3,
#   'years': 1,
#   'you': 13,
#   'your': 7},
#  'deceased': {'\n': 1},
#  'baby': {'\n': 10,
#   'all': 1,
#   'be': 3,
#   'for': 1,
#   'i': 5,
#   "i'll": 7,
#   "i'm": 1,
#   'is': 3,
#   'take': 3,
#   'tell': 1,
#   "what's": 1},
#  'lifeline': {'\n': 1},
#  'finally': {'fall': 2},
#  'levitate': {'\n': 12, 'just': 12},
#  'deaf': {'\n': 1},
#  'leaves': {'\n': 3},
#  'dark': {'\n': 7,
#   'and': 1,
#   'cold': 1,
#   'curtain': 1,
#   'dark': 1,
#   'enough': 2,
#   'inside': 3,
#   'pit': 1},
#  'opulence': {'\n': 1},
#  'hostage': {'to': 1},
#  'eat': {'\n': 1, 'oh': 1},
#  'arrange': {'we': 1},
#  'scare': {'the': 1},
#  'brink': {'of': 1},
#  'touch': {'am': 1, "isn't": 2, 'me': 8, 'out': 1, 'that': 1, 'turns': 6},
#  'tears': {'\n': 2, 'and': 1, 'fall': 1, 'of': 1, "we'll": 1, 'will': 1},
#  'realize': {"you're": 1},
#  'five': {'degrees': 2, 'hundred': 8, 'seconds': 3},
#  "tunnel's": {'light': 1},
#  'wonderful': {'\n': 3},
#  'hopelessness': {'is': 1},
#  'secrets': {'\n': 1},
#  'believer': {'\n': 9, 'believer': 9},
#  'roots': {'\n': 9, 'take': 1},
#  'drops': {'\n': 3},
#  'crying': {'fathers': 1, 'inside': 2, 'out': 1, 'tears': 1},
#  'negative': {'nepotist': 1},
#  'wondered': {'why': 1},
#  'thefading': {'black': 1},
#  'serious': {'and': 1},
#  'today': {'\n': 13, 'not': 3},
#  'curse': {'of': 1, 'oh': 6, 'these': 3},
#  'tin': {'man': 2},
#  'my': {'\n': 3,
#   'age': 2,
#   'baby': 1,
#   'back': 2,
#   'bags': 1,
#   'belief': 1,
#   'blood': 2,
#   'body': 7,
#   "body'": 5,
#   'bones': 4,
#   'book': 1,
#   'breath': 1,
#   'brothers': 1,
#   'brow': 1,
#   'car': 1,
#   'cards': 5,
#   'chest': 3,
#   'classes': 1,
#   'clothes': 1,
#   'conscience': 1,
#   'corresponding': 1,
#   'dear': 1,
#   'demons': 12,
#   'dreams': 1,
#   'drive': 3,
#   'dues': 5,
#   'ears': 3,
#   'eye': 1,
#   'eyes': 23,
#   'face': 1,
#   'fame': 1,
#   'fate': 1,
#   'fault': 16,
#   'fears': 1,
#   'feelings': 1,
#   'flags': 1,
#   'flame': 1,
#   'friend': 3,
#   'friends': 1,
#   'future': 8,
#   'ground': 1,
#   'hair': 1,
#   'hand': 3,
#   'hands': 1,
#   'head': 26,
#   'heart': 17,
#   'heat': 3,
#   'hopeless': 6,
#   'house': 1,
#   'kingdom': 4,
#   'knees': 4,
#   'left': 2,
#   'lesson': 1,
#   'life': 39,
#   'lifeline': 1,
#   'lighter': 1,
#   'lips': 2,
#   'little': 1,
#   'living': 1,
#   'longing': 1,
#   'love': 9,
#   'luck': 8,
#   'match': 1,
#   'message': 1,
#   'middle': 5,
#   'mind': 17,
#   'name': 2,
#   'number': 1,
#   'oh': 1,
#   'old': 1,
#   'only': 1,
#   'own': 4,
#   'papa': 1,
#   'path': 1,
#   'people': 6,
#   'phone': 1,
#   'place': 2,
#   'poems': 1,
#   'pride': 1,
#   'rain': 1,
#   'reasons': 1,
#   'roots': 10,
#   'rust': 1,
#   'screams': 2,
#   'sea': 2,
#   'sense': 1,
#   'shallow': 4,
#   'shooting': 2,
#   'shoulder': 6,
#   'side': 3,
#   'sights': 1,
#   'sins': 4,
#   'sister': 3,
#   'skin': 4,
#   'soul': 5,
#   'spine': 1,
#   'stomach': 1,
#   'studied': 1,
#   'sulking': 1,
#   'surprise': 1,
#   'systems': 3,
#   'thoughts': 1,
#   'throne': 1,
#   'time': 1,
#   'trust': 1,
#   'truth': 2,
#   'veins': 9,
#   'view': 1,
#   'voice': 1,
#   'wall': 2,
#   'way': 7,
#   'weight': 1,
#   'whole': 1,
#   'wildest': 1,
#   'word': 4,
#   'years': 1,
#   'yesterday': 8,
#   'youth': 2},
#  'some': {'arms': 2,
#   'love': 1,
#   'questions': 1,
#   'rocks': 4,
#   'time': 4,
#   'trouble': 2,
#   'were': 16},
#  'few': {'\n': 2},
#  'magnet': {'eyes': 1},
#  'her': {'crimes': 1, 'life': 1, 'love': 1},
#  'lightning': {'before': 1, 'then': 9, 'whiter': 1},
#  'mush': {'\n': 3},
#  'myself': {'\n': 12, 'living': 1},
#  'daily': {'grind': 1},
#  'bloodwood': {'and': 1},
#  'rivers': {'\n': 1},
#  'failed': {'\n': 1},
#  'vicious': {'dove': 1},
#  'rhinestones': {'\n': 1},
#  'country': {'\n': 1},
#  'sends': {'me': 1},
#  'path': {'\n': 4, 'ah': 1, 'to': 1},
#  'awake': {'at': 1, 'now': 1, 'to': 2},
#  'grind': {'\n': 1},
#  'outro': {'\n': 1},
#  'prove': {'yourself': 1},
#  'boy': {'has': 1, 'you': 2},
#  'daddy': {'works': 3},
#  'play': {'\n': 3, "'em": 4, 'it': 3, 'my': 4, 'swing': 1, 'the': 1},
#  'prepare': {'for': 1},
#  'they': {'all': 1,
#   'are': 4,
#   'ask': 1,
#   'believe': 2,
#   'burn': 1,
#   'close': 1,
#   'could': 1,
#   'died': 1,
#   "don't": 4,
#   'dont': 1,
#   'dug': 1,
#   'fall': 1,
#   'get': 2,
#   'grow': 1,
#   'have': 1,
#   'keep': 1,
#   'lead': 3,
#   'make': 1,
#   'may': 1,
#   'never': 4,
#   'push': 1,
#   'say': 17,
#   'see': 5,
#   'seem': 2,
#   'shine': 2,
#   'step': 1,
#   'tell': 1,
#   'telling': 1,
#   'told': 1,
#   'walk': 1,
#   'were': 1,
#   'will': 1,
#   "won't": 4,
#   'would': 1},
#  'coolers': {'as': 1},
#  'cha': {'ching': 12, 'chingaling': 6},
#  'crawl': {'\n': 1},
#  'stared': {'like': 1},
#  'sinners': {'crawl': 1},
#  'breed': {'we': 2},
#  'promises': {'are': 1},
#  'stands': {'and': 1},
#  'lifetime': {'\n': 6},
#  'helps': {'me': 1},
#  'beatup': {'motor': 1},
#  'little': {'about': 1,
#   'bit': 13,
#   'bubble': 1,
#   'home': 1,
#   'lies': 1,
#   'lost': 2,
#   'more': 2,
#   'never': 1,
#   'of': 1,
#   'soul': 4,
#   'too': 6},
#  'wrong': {'\n': 12, 'go': 1},
#  'next': {'to': 11},
#  'easy': {'\n': 4, 'and': 1, 'for': 4, 'on': 1, 'way': 1},
#  'made': {'\n': 2,
#   'in': 1,
#   'inside': 1,
#   'it': 13,
#   'me': 14,
#   'of': 3,
#   'the': 3,
#   'up': 4,
#   'with': 1,
#   'your': 3},
#  'beg': {'you': 2},
#  'circles': {'\n': 1},
#  'wise': {'\n': 1, 'man': 1},
#  'longing': {'stare': 1},
#  'takes': {'\n': 17, 'care': 1, 'is': 2},
#  'taught': {'me': 1},
#  'spotlight': {'\n': 2},
#  'tip': {'of': 1, 'toe': 1},
#  'well': {'\n': 1, 'at': 1, 'i': 6, "i'm": 4, 'it': 3, 'these': 3, 'you': 4},
#  'match': {'\n': 1, 'ooh': 1},
#  'lines': {'\n': 3, 'and': 1, 'keep': 1},
#  'ooo': {'\n': 1, 'ah': 1},
#  'deck': {'of': 1},
#  'remain': {'\n': 2},
#  'oooh': {'\n': 1},
#  'doubts': {'begin': 1},
#  'westcoast': {'\n': 1},
#  'million': {'lies': 1, 'opportunities': 2, 'stories': 1},
#  'children': {'cry': 1},
#  'hate': {'that': 1},
#  'ground': {'\n': 16, 'begins': 1, 'shattered': 1, 'without': 1},
#  'moon': {'\n': 2, 'it': 2, 'that': 1},
#  "she's": {'just': 1, 'young': 1},
#  'truth': {'\n': 5, 'but': 1, 'i': 1, "i've": 1, 'in': 1, 'of': 1},
#  'stepped': {'into': 1},
#  'empires': {'are': 1},
#  'problem': {'lies': 2},
#  "holdin'": {'on': 1},
#  'current': {'drags': 2},
#  'bold': {'\n': 1},
#  "could've": {'gave': 1, 'spoken': 1},
#  "can't": {'believe': 2,
#   'escape': 1,
#   'have': 2,
#   'hear': 2,
#   'i': 1,
#   'relate': 2,
#   'sit': 3,
#   'slow': 8,
#   'talk': 3,
#   'tell': 1},
#  'underdog': {'\n': 6, 'hey': 6},
#  "'til": {"he's": 1, "it's": 3, 'we': 1},
#  'hazy': {'\n': 2},
#  'fade': {'\n': 1, 'away': 3, 'out': 1},
#  'dies': {'\n': 1},
#  'elastic': {'wasted': 1},
#  "leavin'": {'my': 4},
#  'shore': {'\n': 2},
#  'sound': {'\n': 7, 'we': 2},
#  'feeling': {'\n': 1,
#   'far': 2,
#   'just': 2,
#   'like': 2,
#   'me': 1,
#   'miserable': 1,
#   'right': 2},
#  'bird': {'in': 2},
#  'does': {'it': 2},
#  'anybody': {'\n': 1},
#  'tree': {'\n': 1, 'you': 1},
#  'mold': {'\n': 1},
#  'masses': {'\n': 2},
#  'low': {'\n': 14, 'hit': 1, 'life': 7},
#  'festering': {'\n': 1},
#  'beating': {'\n': 3, 'down': 1},
#  'evolving': {'\n': 1},
#  'drowning': {'in': 1},
#  'farmers': {'in': 1},
#  'porch': {'\n': 1},
#  'rose': {'\n': 2},
#  'year': {'\n': 3, 'it': 1, 'seems': 1},
#  'probably': {'give': 1},
#  'collision': {'\n': 1, 'of': 1},
#  'lay': {'\n': 1, 'awake': 1, 'me': 6, 'with': 1},
#  'changing': {'\n': 1, 'and': 1, 'anything': 1, "i'm": 1, 'the': 1, 'who': 5},
#  'filled': {'to': 2, 'with': 3},
#  'sold': {'upon': 1},
#  'phone': {'\n': 1},
#  'wept': {'on': 6},
#  'hear': {'\n': 2,
#   'it': 1,
#   'me': 7,
#   'my': 1,
#   'one': 3,
#   'our': 2,
#   'the': 1,
#   'them': 6,
#   'those': 6,
#   'you': 1,
#   'your': 2},
#  'used': {'to': 7},
#  'vindication': {'\n': 1},
#  'works': {'and': 3},
#  'government': {'\n': 1},
#  'cluttered': {'dreams': 1},
#  'fell': {'\n': 1},
#  'intake': {'\n': 1},
#  'degrees': {'\n': 2},
#  'wants': {'to': 1},
#  'mister': {'c': 1, 'hey': 1},
#  'selene': {'\n': 5},
#  'listening': {'\n': 1},
#  'pop': {'your': 3},
#  'selfish': {'motives': 1},
#  'right': {'\n': 13,
#   'all': 2,
#   'and': 1,
#   'at': 1,
#   'attire': 1,
#   'i': 1,
#   'in': 9,
#   'is': 2,
#   'left': 3,
#   'look': 2,
#   'on': 1,
#   'steadfast': 3,
#   'the': 1,
#   'there': 5,
#   'through': 2,
#   'to': 2},
#  'said': {'\n': 2, 'it': 3, 'that': 2, "what's": 1, 'your': 1, 'yourself': 1},
#  'bags': {'and': 1, 'packed': 1},
#  'begin': {"isn't": 5, 'to': 2},
#  'gate': {'\n': 1},
#  'bolt': {'soon': 1},
#  'sealed': {'\n': 3},
#  'drawn': {'and': 1},
#  'then': {'again': 2,
#   'but': 1,
#   'comes': 1,
#   "don't": 1,
#   'i': 7,
#   "i'd": 1,
#   "i'll": 5,
#   'so': 1,
#   'the': 9,
#   'we': 2,
#   'you': 3,
#   "you'd": 1},
#  "takin'": {'for': 1},
#  'viens': {'me': 1},
#  'freight': {'train': 4},
#  'short': {'\n': 3, 'end': 6, 'of': 3},
#  'yell': {'just': 1},
#  'america': {'\n': 6, "don't": 6},
#  'everyone': {'\n': 3, 'i': 1, 'just': 1, 'love': 2},
#  'yes': {'i': 2},
#  'twenty': {'five': 3, 'miles': 1, 'years': 3},
#  'maybe': {'i': 2, "i'm": 7, 'if': 3, 'then': 2, 'you': 2},
#  'share': {'\n': 4},
#  'granted': {'\n': 1},
#  'slave': {'unto': 1},
#  'seventeen': {'\n': 1},
#  'academy': {'a': 1},
#  'sun': {'\n': 8,
#   'burns': 1,
#   'come': 1,
#   "hasn't": 1,
#   'shines': 2,
#   'that': 1,
#   "won't": 1},
#  'scarecrow': {'\n': 1},
#  'race': {'and': 3, 'horse': 2},
#  'funny': {'\n': 3},
#  "didn't": {'i': 1},
#  'throw': {'my': 1, 'stones': 1},
#  'diamonds': {'and': 1},
#  'thirty': {'lives': 1},
#  'walking': {'a': 1, 'down': 5, 'on': 1, 'the': 11},
#  'forgotten': {'nights': 1},
#  'opus': {'\n': 6},
#  "you'd": {'be': 1,
#   'better': 1,
#   'lay': 1,
#   'rather': 1,
#   'show': 2,
#   'swim': 2,
#   'understand': 1},
#  'drags': {'me': 2},
#  'form': {'a': 1, 'and': 1},
#  'validation': {'on': 2},
#  'judges': {'lay': 1},
#  'earth': {'is': 6},
#  'man': {'\n': 21,
#   'a': 3,
#   'among': 1,
#   'down': 5,
#   'falls': 1,
#   'is': 2,
#   'of': 1,
#   'on': 4,
#   'say': 1,
#   'unit': 1,
#   'who': 10,
#   "who's": 5,
#   'with': 4},
#  'lala': {'la': 2},
#  'smiling': {'from': 1},
#  'catch': {'my': 1, 'ooh': 1},
#  'gone': {'\n': 6, 'and': 1, 'to': 2, 'too': 5},
#  'suppose': {'\n': 1},
#  'bleed': {'on': 1, 'out': 4},
#  'cards': {'all': 1, 'close': 1, 'never': 4, 'vice': 1},
#  'estranging': {'oh': 1},
#  'fail': {'\n': 2, 'and': 1},
#  'still': {'are': 2, 'at': 1, 'i': 6, 'leave': 1, 'you': 8},
#  'slick': {'at': 1},
#  'wish': {'\n': 2, 'i': 4},
#  'changes': {'\n': 4},
#  'talking': {'that': 2},
#  'least': {'\n': 1, "i'll": 1},
#  'pourquoi': {'\n': 13},
#  'belief': {'\n': 1, 'in': 1},
#  'push': {'aside': 1},
#  "other's": {'hearts': 2},
#  'careful': {"don't": 2},
#  'you': {'': 1,
#   '\n': 210,
#   'adore': 1,
#   "ain't": 1,
#   'all': 5,
#   'always': 2,
#   'and': 9,
#   'are': 21,
#   'ask': 4,
#   'asked': 1,
#   'be': 5,
#   'beeline': 2,
#   'believe': 9,
#   'believelieve': 4,
#   'break': 3,
#   'brought': 2,
#   'but': 1,
#   'came': 1,
#   'can': 19,
#   "can't": 3,
#   'cant': 6,
#   'change': 3,
#   'close': 8,
#   'come': 4,
#   'could': 10,
#   'cry': 9,
#   'dare': 1,
#   'do': 3,
#   "don't": 7,
#   'dont': 5,
#   'down': 20,
#   'drew': 2,
#   'ever': 6,
#   'feel': 5,
#   'fell': 1,
#   'follow': 2,
#   'for': 10,
#   'free': 1,
#   'from': 1,
#   'gave': 6,
#   'get': 5,
#   'give': 7,
#   'go': 2,
#   'got': 7,
#   'gotta': 14,
#   'grow': 2,
#   'guys': 1,
#   'have': 4,
#   "have's": 1,
#   'hear': 5,
#   'hell': 2,
#   'hold': 1,
#   'home': 2,
#   'i': 5,
#   "i'd": 1,
#   "i'll": 1,
#   'if': 2,
#   'in': 8,
#   'just': 1,
#   'kiss': 2,
#   'know': 30,
#   'lady': 1,
#   'lead': 1,
#   'left': 1,
#   'let': 2,
#   'look': 1,
#   'lose': 4,
#   'love': 11,
#   'loved': 1,
#   'made': 13,
#   'make': 10,
#   'mean': 5,
#   'meant': 1,
#   'missing': 1,
#   'most': 1,
#   'need': 2,
#   'needed': 1,
#   'never': 3,
#   'oh': 8,
#   'on': 1,
#   'ooh': 1,
#   'over': 3,
#   'painted': 1,
#   'part': 1,
#   'pay': 1,
#   'put': 3,
#   'reach': 1,
#   'remain': 2,
#   'right': 2,
#   'rip': 2,
#   'round': 2,
#   'said': 3,
#   'sang': 1,
#   'save': 5,
#   'say': 8,
#   'searched': 1,
#   'see': 11,
#   'show': 8,
#   'sing': 6,
#   'skip': 3,
#   'smiled': 1,
#   'so': 1,
#   'something': 1,
#   'stand': 3,
#   'start': 1,
#   'stay': 2,
#   'still': 4,
#   'take': 4,
#   'talk': 1,
#   'taught': 1,
#   'tell': 7,
#   'tend': 1,
#   'that': 1,
#   'the': 1,
#   'there': 3,
#   'think': 18,
#   'thought': 3,
#   'to': 1,
#   'today': 3,
#   'touch': 10,
#   'tried': 1,
#   'trust': 5,
#   'try': 1,
#   'turn': 3,
#   'understand': 6,
#   'up': 2,
#   'vagabond': 2,
#   'wait': 8,
#   'walked': 1,
#   'wanna': 2,
#   'want': 11,
#   'wanted': 4,
#   'were': 34,
#   'what': 5,
#   'when': 2,
#   'will': 7,
#   'window': 1,
#   'would': 5,
#   'wrong': 3,
#   'you': 22,
#   "you'd": 2},
#  'clocks': {'\n': 1},
#  'pride': {'\n': 1},
#  'bigger': {'but': 5, 'things': 1},
#  'assess': {'we': 1},
#  'static': {'\n': 1},
#  'dues': {'to': 5},
#  'safe': {'and': 1, 'man': 1},
#  'saying': {"it's": 2},
#  'trouble': {'\n': 14, 'finds': 1, 'found': 5, 'i': 12, "i've": 2},
#  'bones': {'\n': 3, 'straight': 1},
#  'attest': {'\n': 1},
#  'holden': {'wrecks': 1},
#  'amsterdam': {'\n': 2},
#  'wanted': {'me': 4, 'the': 1, 'to': 1, 'your': 1},
#  'lot': {'about': 1, 'and': 2, 'of': 2, "that's": 1, 'to': 4},
#  'unit': {'at': 1},
#  "rifle's": {'sight': 1},
#  'torn': {'in': 1},
#  'cherry': {'bomb': 4},
#  'star': {'\n': 3, 'like': 2},
#  'from': {'\n': 4,
#   'a': 3,
#   'above': 1,
#   'all': 2,
#   'anyone': 1,
#   'broken': 1,
#   'desert': 1,
#   'dust': 3,
#   'far': 1,
#   'farmers': 1,
#   'good': 3,
#   'heartache': 1,
#   'here': 11,
#   'inside': 1,
#   'kintore': 1,
#   'me': 7,
#   'perfect': 1,
#   'right': 1,
#   'seeing': 1,
#   'the': 16,
#   'up': 1,
#   'where': 1,
#   'you': 2,
#   'your': 2},
#  'appeal': {'\n': 1},
#  'these': {'are': 6,
#   'blocks': 1,
#   'corners': 1,
#   'days': 12,
#   'eyes': 4,
#   'halls': 1,
#   'hands': 2,
#   'lands': 1,
#   'lights': 2,
#   'nights': 3,
#   'people': 1,
#   'places': 1,
#   'plans': 1,
#   'seagulls': 1,
#   'sorrows': 3,
#   'walls': 2,
#   'words': 2,
#   'years': 2},
#  'ending': {'\n': 1, 'is': 2},
#  'falling': {'\n': 3,
#   'crow': 1,
#   'crows': 2,
#   'down': 7,
#   'i': 4,
#   "i'm": 5,
#   'like': 1,
#   'short': 1,
#   'then': 1,
#   'too': 1},
#  'see': {'\n': 17,
#   'are': 1,
#   'clearly': 12,
#   'in': 1,
#   'is': 3,
#   'it': 10,
#   'me': 6,
#   'my': 1,
#   'of': 2,
#   'that': 1,
#   'the': 9,
#   'these': 2,
#   "we'll": 1,
#   'what': 2,
#   "what's": 1,
#   'whats': 1,
#   'your': 2},
#  'standing': {'here': 1},
#  'town': {'\n': 16, 'and': 6, 'can': 4, 'this': 1},
#  'resolutions': {'and': 4},
#  'laughed': {'ooh': 1},
#  'cause': {'\n': 12,
#   'after': 3,
#   'heaven': 1,
#   'im': 4,
#   'its': 5,
#   'these': 2,
#   'you': 2,
#   "you've": 2},
#  'volumes': {'\n': 1},
#  'hearts': {'\n': 5, 'to': 1, 'yeah': 1},
#  'hanging': {'on': 1},
#  'missing': {'each': 8, 'life': 1},
#  'fit': {'in': 1, 'right': 4, 'the': 2},
#  'wealth': {'\n': 1},
#  'chase': {'a': 2},
#  'cross': {'my': 1},
#  'adore': {'and': 1, 'lately': 1},
#  'beast': {'inside': 1},
#  "zippin'": {'off': 1},
#  'lighter': {'\n': 1},
#  'capable': {'collision': 1, 'commissions': 1},
#  'radio': {'is': 2},
#  'weep': {'for': 1},
#  'summertime': {'\n': 3},
#  'shoot': {"'em": 1},
#  'shooting': {'down': 1, 'star': 2},
#  'strobing': {'streets': 1},
#  'paid': {'\n': 1},
#  'living': {'\n': 5,
#   "'til": 1,
#   'and': 1,
#   'but': 1,
#   'in': 18,
#   'just': 1,
#   'life': 2,
#   'living': 5,
#   'musical': 3,
#   'room': 1,
#   'the': 4,
#   'till': 2},
#  'waiting': {'at': 1, 'for': 7, 'on': 1, 'to': 6, 'up': 2},
#  'gets': {'drunk': 1, 'hard': 1, 'me': 2},
#  'boots': {'oh': 3},
#  'staying': {'in': 1},
#  'best': {'and': 1, "you'll": 1},
#  'holding': {'it': 5, 'on': 3, 'the': 1, 'you': 7},
#  'many': {'choices': 4, 'noises': 3, 'sleepless': 3, 'voices': 12},
#  'staring': {'as': 1, 'shadows': 1},
#  'gray': {'\n': 1},
#  'new': {'age': 12, 'day': 1},
#  'emptiness': {'inside': 1, 'is': 1},
#  'flights': {'up': 1},
#  'gold': {'\n': 19, 'and': 3, 'gold': 12},
#  'youre': {'lying': 1, 'stuck': 1},
#  'beat': {'\n': 1, 'around': 1, 'it': 1, 'the': 3},
#  'born': {'for': 3, 'it': 3, 'to': 2},
#  'birds': {'and': 1, 'come': 1},
#  'goes': {'\n': 4, 'a': 1, 'along': 2, 'beyond': 1, 'in': 2},
#  'burden': {'came': 1},
#  'slanted': {'view': 1},
#  'settle': {'down': 1, 'in': 1},
#  'sunrise': {'\n': 1},
#  'rocks': {'\n': 1, 'right': 2, 'up': 2},
#  'bus': {'\n': 2},
#  'grave': {'\n': 4, 'and': 2},
#  'blessing': {'of': 1},
#  'mistake': {'\n': 1},
#  'x': {'\n': 7, 'the': 1},
#  'melodies': {'mumble': 1},
#  'vagabond': {'\n': 2},
#  'glows': {'\n': 2},
#  'fool': {'\n': 4},
#  'wine': {'and': 1},
#  'mental': {'health': 1},
#  'door': {'\n': 16, 'baby': 1},
#  'pictures': {'\n': 1, 'dry': 1, 'of': 1},
#  'bedroom': {'\n': 2},
#  'fourth': {'of': 1},
#  'redemption': {'\n': 3},
#  'writing': {'my': 1, 'stuck': 1},
#  'valley': {'where': 1},
#  'book': {'of': 1},
#  'overages': {"screamin'": 1},
#  'taker': {'\n': 2},
#  'effortless': {'\n': 1},
#  'knowing': {"it's": 1},
#  'wreck': {'what': 1},
#  'walk': {'\n': 1, 'all': 1, 'away': 3, 'five': 8, 'for': 1, 'me': 3, 'on': 1},
#  "kissin'": {'lessons': 2},
#  'show': {'\n': 3, 'me': 13, 'them': 1, 'you': 4},
#  'commodities': {'a': 1},
#  'second': {'\n': 2, 'and': 1, 'chances': 9, 'that': 3, 'things': 1},
#  'ive': {'been': 1, 'come': 1, 'loaded': 3, 'lost': 1},
#  'lyrics': {'leave': 1},
#  'starting': {'to': 1},
#  'doesnt': {'matter': 15},
#  'distance': {'\n': 1, 'seventeen': 1, 'taking': 1, 'there': 1},
#  'sisters': {'the': 2},
#  'lips': {'\n': 1, 'and': 2},
#  'hardly': {'stand': 1},
#  'moi': {'\n': 1},
#  'explain': {"you're": 1},
#  'somebody': {'\n': 1, 'else': 6},
#  'honey': {'\n': 3, "it's": 2},
#  'ourselves': {'\n': 1},
#  "runnin'": {'down': 2},
#  'patience': {'\n': 1, 'of': 1},
#  'london': {'sounds': 2},
#  'lights': {'\n': 2, 'and': 5, 'big': 2, 'fade': 1, 'that': 2, 'up': 3},
#  'clouds': {'above': 1},
#  'crash': {'collision': 1},
#  'lady': {'never': 1},
#  'window': {'\n': 4, 'pane': 2},
#  'theres': {'nothing': 12, 'so': 1},
#  'looked': {'a': 2, 'so': 1},
#  'rise': {'\n': 3, 'rise': 10, 'to': 8, 'up': 10},
#  'wanna': {'\n': 2,
#   'be': 5,
#   'bow': 1,
#   'change': 2,
#   'dream': 8,
#   'hear': 3,
#   'join': 6,
#   'leave': 3,
#   'let': 3,
#   'live': 6,
#   'make': 1,
#   'see': 3,
#   'try': 2,
#   'wait': 3},
#  'help': {'me': 8},
#  'inside': {'\n': 10,
#   'and': 1,
#   'is': 1,
#   'me': 3,
#   'my': 5,
#   'of': 1,
#   "there's": 1,
#   'you': 1,
#   'your': 2},
#  'shot': {'a': 6, 'shot': 12},
#  'desolation': {'tell': 1, 'tragedy': 2},
#  'lust': {'\n': 1},
#  'whenever': {"i'm": 6},
#  'whole': {'again': 1, 'inside': 1, 'life': 1},
#  'arrived': {'at': 1},
#  'saturday': {'night': 1},
#  'false': {'false': 1, 'from': 1, 'hope': 1},
#  'tomb': {'\n': 1},
#  "you're": {'a': 5,
#   'afraid': 1,
#   'all': 16,
#   'always': 1,
#   'at': 1,
#   'back': 2,
#   'basic': 1,
#   'crying': 1,
#   'easy': 1,
#   'falling': 2,
#   'feeling': 1,
#   'fine': 1,
#   'gone': 2,
#   'gonna': 2,
#   'here': 1,
#   'just': 4,
#   'meant': 2,
#   'my': 2,
#   'never': 1,
#   'on': 1,
#   'paid': 1,
#   'shattered': 3,
#   'the': 7,
#   "zippin'": 1},
#  'roll': {'\n': 4, 'down': 1},
#  'miserable': {'\n': 1},
#  'holy': {'road': 2},
#  'sleeps': {'at': 2},
#  'hour': {'\n': 3, 'is': 1},
#  'clean': {'again': 1},
#  'lately': {'\n': 1, 'all': 2},
#  'loose': {'\n': 1},
#  'dynamite': {'\n': 3},
#  'shivering': {'\n': 1},
#  'palms': {'of': 4},
#  'sleep': {'\n': 2, 'at': 4, 'so': 1, 'while': 6},
#  'mmmmouth': {'of': 12},
#  'aside': {'the': 1},
#  'far': {'\n': 5, 'away': 5, 'from': 6, 'to': 1, "we've": 9},
#  'stood': {'in': 1},
#  'whoa': {'': 6, '\n': 14, 'dance': 1, 'whoa': 24},
#  'bow': {'to': 1, 'woah': 3},
#  'breaks': {'into': 1},
#  'sands': {'\n': 1},
#  'another': {'day': 7,
#   'door': 6,
#   'guy': 4,
#   'high': 6,
#   'low': 6,
#   'man': 1,
#   'trying': 3,
#   'year': 1},
#  'strangest': {'of': 1},
#  'dress': {'\n': 1},
#  'certain': {'\n': 1},
#  'lair': {'\n': 1},
#  'bang': {'\n': 3, 'bang': 6},
#  'sea': {'\n': 4, 'of': 1, 'ohooh': 2},
#  'chances': {'\n': 9},
#  'stare': {'\n': 1, 'at': 1, 'on': 1},
#  'cursed': {'\n': 2, 'me': 4},
#  'better': {'free': 1, 'in': 3, 'or': 1, 'start': 2, 'tell': 1},
#  'reason': {'\n': 5, 'breaking': 1, "i'm": 1, 'to': 1, 'why': 1},
#  'black': {'\n': 1},
#  'sentiment': {'\n': 1},
#  'let': {"'em": 4,
#   'all': 1,
#   'go': 4,
#   'it': 22,
#   'let': 2,
#   'loose': 1,
#   'me': 28,
#   'my': 1,
#   'the': 7,
#   'them': 3,
#   'this': 8,
#   'you': 20},
#  'gatekeeper': {'\n': 2},
#  'etiquette': {'\n': 1},
#  'ohh': {'\n': 1, 'we': 2},
#  'sang': {'a': 1, 'along': 1},
#  'deficits': {'\n': 1},
#  'worse': {'is': 1},
#  'master': {'of': 2},
#  'prettiest': {'of': 1},
#  'cellphone': {'\n': 1},
#  'hunter': {'waiting': 1},
#  'mud': {'\n': 1},
#  'save': {'\n': 4, 'me': 11, 'my': 2, 'their': 1, 'us': 5},
#  'sights': {'on': 1},
#  'woah': {'\n': 12, 'crying': 1, 'how': 3, 'woah': 8},
#  'car': {"i'll": 1},
#  'praying': {'for': 1, 'to': 1},
#  'bay': {'side': 2},
#  'easier': {'\n': 1, 'and': 10, 'somehow': 9},
#  "they're": {'crashing': 2, 'here': 1, 'on': 4, 'saying': 2},
#  "love's": {'lyrics': 1},
#  'prefer': {'the': 1},
#  'talked': {'\n': 2},
#  'ears': {'and': 3},
#  'destruction': {'\n': 1},
#  'first': {'\n': 1,
#   'class': 1,
#   'comes': 1,
#   'did': 1,
#   "kissin'": 2,
#   'met': 1,
#   'things': 1,
#   'time': 1,
#   'to': 1},
#  'tragedy': {'\n': 2},
#  'cover': {'\n': 1, 'up': 6},
#  'empty': {'hotel': 1, 'space': 4},
#  'musical': {'\n': 3},
#  'stale': {'\n': 1, 'and': 1},
#  'rolling': {'freight': 4, 'over': 1},
#  'chairman': {'mao': 1},
#  'speak': {'\n': 2, 'speak': 18, 'to': 6, 'your': 3},
#  'fresh': {'breath': 1},
#  ...}

# %%
count_dict = build_count_dict('lyrics')

NUM_WORDS = 100
START_WORD = '\n'

cur_word = START_WORD
for i in range(NUM_WORDS):
    print(cur_word, end=" ")
    cur_word = random_weighted_key(count_dict[cur_word])
# Out:
#  don't look tired of a million opportunities
#  my yesterday
#  rock bottom of the reason
#  open up to be asked me love love you were the thunder feel it and i keep your head up hill from here we start
#  was only comes a fool
#  oh don't work i can
#  maybe i'm just levitate
#  for this is it on me and speak
#  everything
#  i am me voir très bien ouh la lala la
#  i will not enough
#  whenever i'm just one
#  and now no these eyes they keep
